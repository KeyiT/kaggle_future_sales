# %%
import pandas as pd
import numpy as np
import os
import data
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline 
from tqdm import tqdm_notebook as tn
import gc

import sklearn
from sklearn.model_selection import KFold
from sklearn.preprocessing import RobustScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error
from math import sqrt

import category_encoders as ce
from hyperopt import tpe, fmin, hp, Trials

import lightgbm as lgb

from itertools import product
# Out:
# /Users/keyitang/miniconda3/envs/kaggleFutureSales/lib/python3.6/site-packages/lightgbm/__init__.py:46: UserWarning: Starting from version 2.2.1, the library file in distribution wheels for macOS is built by the Apple Clang (Xcode_8.3.1) compiler.
# This means that in case of installing LightGBM from PyPI via the ``pip install lightgbm`` command, you don't need to install the gcc compiler anymore.
# Instead of that, you need to install the OpenMP library, which is required for running LightGBM on the system with the Apple Clang compiler.
# You can install the OpenMP library by the following command: ``brew install libomp``.
#   "You can install the OpenMP library by the following command: ``brew install libomp``.", UserWarning)

# %%
def downcast_dtypes(df):
    '''
        Changes column types in the dataframe: 
                
                `float64` type to `float32`
                `int64`   type to `int32`
    '''
    
    # Select columns to downcast
    float_cols = [c for c in df if df[c].dtype == "float64"]
    int_cols =   [c for c in df if df[c].dtype == "int64"]
    
    # Downcast
    df[float_cols] = df[float_cols].astype(np.float32)
    df[int_cols]   = df[int_cols].astype(np.int32)
    
    return df

# %% [markdown]
# ## Read Data

# %%
DATA_FOLDER = os.path.join(data.DATA_ROOT, "readonly")
TMP_FOLDER = os.path.join(data.DATA_ROOT, "tmp")
#DATA_FOLDER = "../input"
#TMP_FOLDER = os.path.join(data.DATA_ROOT, "tmp")

VALIDATION_FOLDER = os.path.join(TMP_FOLDER, "validation")
SUBMISSION_FOLDER = os.path.join(TMP_FOLDER, "submission")

# %%
FOLDER = VALIDATION_FOLDER
#FOLDER = SUBMISSION_FOLDER

train_data_path = os.path.join(FOLDER, "train.csv")
test_data_path = os.path.join(FOLDER, "test.csv")

train_data = pd.read_csv(train_data_path).drop(columns=['month', 'date_block_num'])
test_data = pd.read_csv(test_data_path).drop(columns=['month', 'date_block_num'])

train_data = downcast_dtypes(train_data)
test_data = downcast_dtypes(test_data)

print("train data shape: " + str(train_data.shape))
train_data.dtypes
# Out:
# train data shape: (6186922, 88)
# item_category_id                         int32
# shop_id                                  int32
# item_id                                  int32
# target                                 float32
# shop_id_count_month_lag_1              float32
# shop_id_sale_month_lag_1               float32
# item_id_count_month_lag_1              float32
# item_id_sale_month_lag_1               float32
# item_price_mean_month_lag_1            float32
# item_price_std_month_lag_1             float32
# item_shop_cnt_sum_month_lag_1          float32
# item_shop_cnt_std_month_lag_1          float32
# item_shop_sale_sum_month_lag_1         float32
# item_shop_sale_std_month_lag_1         float32
# item_category_id_count_month_lag_1     float32
# item_category_id_sale_month_lag_1      float32
# shop_id_count_month_lag_2              float32
# shop_id_sale_month_lag_2               float32
# item_id_count_month_lag_2              float32
# item_id_sale_month_lag_2               float32
# item_price_mean_month_lag_2            float32
# item_price_std_month_lag_2             float32
# item_shop_cnt_sum_month_lag_2          float32
# item_shop_cnt_std_month_lag_2          float32
# item_shop_sale_sum_month_lag_2         float32
# item_shop_sale_std_month_lag_2         float32
# item_category_id_count_month_lag_2     float32
# item_category_id_sale_month_lag_2      float32
# shop_id_count_month_lag_3              float32
# shop_id_sale_month_lag_3               float32
#                                         ...
# item_shop_cnt_sum_month_lag_5          float32
# item_shop_cnt_std_month_lag_5          float32
# item_shop_sale_sum_month_lag_5         float32
# item_shop_sale_std_month_lag_5         float32
# item_category_id_count_month_lag_5     float32
# item_category_id_sale_month_lag_5      float32
# shop_id_count_month_lag_6              float32
# shop_id_sale_month_lag_6               float32
# item_id_count_month_lag_6              float32
# item_id_sale_month_lag_6               float32
# item_price_mean_month_lag_6            float32
# item_price_std_month_lag_6             float32
# item_shop_cnt_sum_month_lag_6          float32
# item_shop_cnt_std_month_lag_6          float32
# item_shop_sale_sum_month_lag_6         float32
# item_shop_sale_std_month_lag_6         float32
# item_category_id_count_month_lag_6     float32
# item_category_id_sale_month_lag_6      float32
# shop_id_count_month_lag_12             float32
# shop_id_sale_month_lag_12              float32
# item_id_count_month_lag_12             float32
# item_id_sale_month_lag_12              float32
# item_price_mean_month_lag_12           float32
# item_price_std_month_lag_12            float32
# item_shop_cnt_sum_month_lag_12         float32
# item_shop_cnt_std_month_lag_12         float32
# item_shop_sale_sum_month_lag_12        float32
# item_shop_sale_std_month_lag_12        float32
# item_category_id_count_month_lag_12    float32
# item_category_id_sale_month_lag_12     float32
# Length: 88, dtype: object

# %% [markdown]
# ## Make X and y

# %%
train_y = train_data['target']
train_x = train_data.drop(['target'], axis='columns')
feature_names = train_x.columns.tolist()

if 'target' in test_data.columns.tolist():
    test_x = test_data.drop(['target'], axis='columns')
    test_y = test_data['target']
else:
    test_x = test_data

# %% [markdown]
# ## Clipping

# %%
train_y.loc[train_y > 40] = 40
if test_y is not None:
    test_y.loc[test_y > 40] = 40
# Out:
# /Users/keyitang/miniconda3/envs/kaggleFutureSales/lib/python3.6/site-packages/pandas/core/indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %% [markdown]
# ## Categorical Feature Encoding

# %%
categorical_columns = [
    'shop_id', 'item_id', 'item_category_id'
]

# %%
# Leave-One-Out Encoding
categorical_encoder = ce.LeaveOneOutEncoder(cols=categorical_columns, impute_missing=False, drop_invariant=True)
categorical_encoder.fit(train_x, train_y)

train_x = categorical_encoder.transform(train_x)
test_x = categorical_encoder.transform(test_x)

train_x = downcast_dtypes(train_x)
test_x = downcast_dtypes(test_x)

train_x.dtypes
# Out:
# item_category_id                       float32
# shop_id                                float32
# item_id                                float32
# shop_id_count_month_lag_1              float32
# shop_id_sale_month_lag_1               float32
# item_id_count_month_lag_1              float32
# item_id_sale_month_lag_1               float32
# item_price_mean_month_lag_1            float32
# item_price_std_month_lag_1             float32
# item_shop_cnt_sum_month_lag_1          float32
# item_shop_cnt_std_month_lag_1          float32
# item_shop_sale_sum_month_lag_1         float32
# item_shop_sale_std_month_lag_1         float32
# item_category_id_count_month_lag_1     float32
# item_category_id_sale_month_lag_1      float32
# shop_id_count_month_lag_2              float32
# shop_id_sale_month_lag_2               float32
# item_id_count_month_lag_2              float32
# item_id_sale_month_lag_2               float32
# item_price_mean_month_lag_2            float32
# item_price_std_month_lag_2             float32
# item_shop_cnt_sum_month_lag_2          float32
# item_shop_cnt_std_month_lag_2          float32
# item_shop_sale_sum_month_lag_2         float32
# item_shop_sale_std_month_lag_2         float32
# item_category_id_count_month_lag_2     float32
# item_category_id_sale_month_lag_2      float32
# shop_id_count_month_lag_3              float32
# shop_id_sale_month_lag_3               float32
# item_id_count_month_lag_3              float32
#                                         ...
# item_shop_cnt_sum_month_lag_5          float32
# item_shop_cnt_std_month_lag_5          float32
# item_shop_sale_sum_month_lag_5         float32
# item_shop_sale_std_month_lag_5         float32
# item_category_id_count_month_lag_5     float32
# item_category_id_sale_month_lag_5      float32
# shop_id_count_month_lag_6              float32
# shop_id_sale_month_lag_6               float32
# item_id_count_month_lag_6              float32
# item_id_sale_month_lag_6               float32
# item_price_mean_month_lag_6            float32
# item_price_std_month_lag_6             float32
# item_shop_cnt_sum_month_lag_6          float32
# item_shop_cnt_std_month_lag_6          float32
# item_shop_sale_sum_month_lag_6         float32
# item_shop_sale_std_month_lag_6         float32
# item_category_id_count_month_lag_6     float32
# item_category_id_sale_month_lag_6      float32
# shop_id_count_month_lag_12             float32
# shop_id_sale_month_lag_12              float32
# item_id_count_month_lag_12             float32
# item_id_sale_month_lag_12              float32
# item_price_mean_month_lag_12           float32
# item_price_std_month_lag_12            float32
# item_shop_cnt_sum_month_lag_12         float32
# item_shop_cnt_std_month_lag_12         float32
# item_shop_sale_sum_month_lag_12        float32
# item_shop_sale_std_month_lag_12        float32
# item_category_id_count_month_lag_12    float32
# item_category_id_sale_month_lag_12     float32
# Length: 87, dtype: object

# %% [markdown]
# ## Imputation

# %%
train_x.fillna(0, inplace=True)
test_x.fillna(0, inplace=True)

train_y.fillna(0, inplace=True)
test_y.fillna(0, inplace=True)

# %% [markdown]
# ## Normalization

# %%
normalizer = RobustScaler()
normalizer.fit(train_x)

train_x = normalizer.transform(train_x)
test_x = normalizer.transform(test_x)

# train_y = train_y / 20
# if test_y is not None:
#     test_y = test_y / 20.0

# %% [markdown]
# ## Model Training

# %%
lgb_params = {
               'feature_fraction': 0.75,
               'metric': 'rmse',
               'nthread':3, 
               'min_data_in_leaf': 58470, 
               'bagging_fraction': 0.75, 
               'learning_rate': 0.03, 
               'objective': 'mse', 
               'bagging_seed': 2**7, 
               'num_leaves': 2**9,
               'bagging_freq':1,
               'max_depth': 10,
               'verbose':0 
              }

lgb_dataset = lgb.Dataset(train_x, label=train_y)

print("start training...")
model = lgb.train(lgb_params, lgb_dataset, 100)

pred_train_y = model.predict(train_x)
#print('Train R-squared for LightGBM is %f' % r2_score(train_y, pred_y))
    
pred_test_y = model.predict(test_x)
# Out:
# start training...

# %%
train_y_tmp = train_y.copy()
test_y_tmp = test_y.copy()

train_y_tmp[train_y_tmp>20] = 20.0
pred_train_y[pred_train_y>20] = 20.0 
print('Train R-squared for LightGBM is %f' % r2_score(train_y_tmp, pred_train_y))
print('Train msre is: ' + str(sqrt(mean_squared_error(train_y_tmp, pred_train_y))))

if test_y is not None:
    test_y_tmp[test_y_tmp>20] = 20.0
    pred_test_y[pred_test_y>20] = 20.0 
    print('Test R-squared for LightGBM is %f' % r2_score(test_y_tmp, pred_test_y))
    print('Test msre is: ' + str(sqrt(mean_squared_error(test_y_tmp, pred_test_y))))
    
gc.collect();
# Out:
# Train R-squared for LightGBM is 0.268050
# Train msre is: 1.0166271399383389
# Test R-squared for LightGBM is 0.107186
# Test msre is: 1.0735659013397745

# %% [markdown]
# ### Pick Most Important Features

# %%
feature_importances = pd.DataFrame(
    {
        'feature_name': feature_names,
        'feature_importance': model.feature_importance().tolist()
    }
)

feature_importances.sort_values('feature_importance', ascending=False, inplace=True)
important_feature_names = set(feature_importances[:30]['feature_name'].tolist())

important_feature_names

feature_boolean_mask = np.asarray(list(
    map(
        lambda feature_name: feature_name in important_feature_names,
        feature_names
    )
))

train_x = train_x[:, feature_boolean_mask]
test_x = test_x[:, feature_boolean_mask]

lgb_dataset = lgb.Dataset(train_x, label=train_y)

# %%
del model, train_x
gc.collect();

# %% [markdown]
# ## Hyper-parameter Tuning

# %%
test_y_pred_list = list()
def objective(hyper_param):
    
    print("hyper_params: " + str(hyper_param))
    max_depth, num_leaves, min_data_in_leaf = hyper_param
    
    lgb_params = {
               'feature_fraction': 0.75,
               'metric': 'rmse',
               'nthread':3, 
               'min_data_in_leaf': int(min_data_in_leaf), 
               'bagging_fraction': 0.75, 
               'learning_rate': 0.03, 
               'objective': 'mse', 
               'bagging_seed': 2**7, 
               'num_leaves': int(num_leaves),
               'max_depth': int(max_depth),
               'bagging_freq':1,
               'verbose':0 
              }
    print("start training..." + str(len(test_y_pred_list)))
    model = lgb.train(lgb_params, lgb_dataset, 100)
    pred_test_y = model.predict(test_x)
    
    pred_test_y[pred_test_y>20] = 20.0 
    result = sqrt(mean_squared_error(test_y_tmp, pred_test_y))
    test_y_pred_list.append(pred_test_y)
    
    gc.collect();
    
    return result


# tuning algorithm
tpe_algo = tpe.suggest

# search space
space = [
    hp.quniform('max_depth', 5, 10, 1),
    hp.quniform('num_leaves', 2**5, 2**10, 5),
    hp.quniform('min_data_in_leaf', 2**5, 10**4, 5)
]

# history
tpe_trials = Trials()

# %%
# Run 2000 evals with the tpe algorithm
tpe_best = fmin(fn=objective, space=space, algo=tpe_algo, trials=tpe_trials, max_evals=1000, rstate= np.random.RandomState(50))

print(tpe_best)
# Out:
# hyper_params: (8.0, 1020.0, 5860.0)
# start training...0
# hyper_params: (8.0, 885.0, 4530.0)
# start training...1
# hyper_params: (9.0, 775.0, 9835.0)
# start training...2
# hyper_params: (7.0, 435.0, 655.0)
# start training...3
# hyper_params: (6.0, 40.0, 8950.0)
# start training...4
# hyper_params: (6.0, 405.0, 4390.0)
# start training...5
# hyper_params: (9.0, 660.0, 3755.0)
# start training...6
# hyper_params: (7.0, 305.0, 7800.0)
# start training...7
# hyper_params: (9.0, 555.0, 4425.0)
# start training...8
# hyper_params: (9.0, 775.0, 5535.0)
# start training...9
# hyper_params: (6.0, 585.0, 7245.0)
# start training...10
# hyper_params: (6.0, 835.0, 200.0)
# start training...11
# hyper_params: (10.0, 130.0, 2365.0)
# start training...12
# hyper_params: (6.0, 670.0, 6905.0)
# start training...13
# hyper_params: (7.0, 950.0, 4545.0)
# start training...14
# hyper_params: (5.0, 355.0, 7075.0)
# start training...15
# hyper_params: (7.0, 85.0, 5785.0)
# start training...16
# hyper_params: (10.0, 195.0, 9615.0)
# start training...17
# hyper_params: (5.0, 565.0, 975.0)
# start training...18
# hyper_params: (9.0, 1000.0, 5870.0)
# start training...19
# hyper_params: (7.0, 445.0, 80.0)
# start training...20
# hyper_params: (5.0, 255.0, 1395.0)
# start training...21
# hyper_params: (8.0, 460.0, 90.0)
# start training...22
# hyper_params: (6.0, 810.0, 2730.0)
# start training...23
# hyper_params: (7.0, 650.0, 1110.0)
# start training...24
# hyper_params: (5.0, 485.0, 2180.0)
# start training...25
# hyper_params: (6.0, 860.0, 3460.0)
# start training...26
# hyper_params: (8.0, 730.0, 520.0)
# start training...27
# hyper_params: (8.0, 735.0, 1740.0)
# start training...28
# hyper_params: (8.0, 370.0, 555.0)
# start training...29
# hyper_params: (8.0, 200.0, 3185.0)
# start training...30
# hyper_params: (8.0, 325.0, 670.0)
# start training...31
# hyper_params: (7.0, 380.0, 2915.0)
# start training...32
# hyper_params: (8.0, 265.0, 1625.0)
# start training...33
# hyper_params: (10.0, 495.0, 3780.0)
# start training...34
# hyper_params: (9.0, 410.0, 2150.0)
# start training...35
# hyper_params: (7.0, 165.0, 8525.0)
# start training...36
# hyper_params: (8.0, 620.0, 5315.0)
# start training...37
# hyper_params: (9.0, 510.0, 6345.0)
# start training...38
# hyper_params: (7.0, 270.0, 4885.0)
# start training...39
# hyper_params: (9.0, 420.0, 3960.0)
# start training...40
# hyper_params: (8.0, 40.0, 490.0)
# start training...41
# hyper_params: (7.0, 40.0, 2575.0)
# start training...42
# hyper_params: (6.0, 115.0, 1670.0)
# start training...43
# hyper_params: (10.0, 45.0, 1185.0)
# start training...44
# hyper_params: (9.0, 970.0, 4100.0)
# start training...45
# hyper_params: (6.0, 905.0, 7730.0)
# start training...46
# hyper_params: (7.0, 230.0, 1995.0)
# start training...47
# hyper_params: (8.0, 100.0, 3320.0)
# start training...48
# hyper_params: (9.0, 315.0, 9830.0)
# start training...49
# hyper_params: (7.0, 540.0, 9100.0)
# start training...50
# hyper_params: (8.0, 160.0, 275.0)
# start training...51
# hyper_params: (5.0, 705.0, 885.0)
# start training...52
# hyper_params: (6.0, 610.0, 40.0)
# start training...53
# hyper_params: (10.0, 60.0, 4825.0)
# start training...54
# hyper_params: (7.0, 800.0, 6290.0)
# start training...55
# hyper_params: (6.0, 135.0, 2935.0)
# start training...56
# hyper_params: (8.0, 895.0, 1345.0)
# start training...57
# hyper_params: (7.0, 220.0, 2450.0)
# start training...58
# hyper_params: (9.0, 335.0, 730.0)
# start training...59
# hyper_params: (5.0, 455.0, 1900.0)
# start training...60
# hyper_params: (8.0, 290.0, 4405.0)
# start training...61
# hyper_params: (6.0, 575.0, 455.0)
# start training...62
# hyper_params: (7.0, 660.0, 3615.0)
# start training...63
# hyper_params: (10.0, 755.0, 5250.0)
# start training...64
# hyper_params: (6.0, 565.0, 450.0)
# start training...65
# hyper_params: (5.0, 690.0, 1375.0)
# start training...66
# hyper_params: (6.0, 620.0, 270.0)
# start training...67
# hyper_params: (6.0, 525.0, 845.0)
# start training...68
# hyper_params: (5.0, 385.0, 1115.0)
# start training...69
# hyper_params: (7.0, 480.0, 3055.0)
# start training...70
# hyper_params: (6.0, 840.0, 1490.0)
# start training...71
# hyper_params: (6.0, 590.0, 2220.0)
# start training...72
# hyper_params: (7.0, 430.0, 2625.0)
# start training...73
# hyper_params: (8.0, 550.0, 70.0)
# start training...74
# hyper_params: (5.0, 930.0, 1835.0)
# start training...75
# hyper_params: (7.0, 770.0, 430.0)
# start training...76
# hyper_params: (8.0, 350.0, 2315.0)
# start training...77
# hyper_params: (7.0, 680.0, 1040.0)
# start training...78
# hyper_params: (6.0, 70.0, 7950.0)
# start training...79
# hyper_params: (5.0, 400.0, 3990.0)
# start training...80
# hyper_params: (8.0, 475.0, 6645.0)
# start training...81
# hyper_params: (7.0, 725.0, 2065.0)
# start training...82
# hyper_params: (9.0, 635.0, 2700.0)
# start training...83
# hyper_params: (6.0, 795.0, 670.0)
# start training...84
# hyper_params: (7.0, 990.0, 5820.0)
# start training...85
# hyper_params: (9.0, 510.0, 1575.0)
# start training...86
# hyper_params: (8.0, 285.0, 320.0)
# start training...87
# hyper_params: (7.0, 430.0, 1260.0)
# start training...88
# hyper_params: (8.0, 1020.0, 3480.0)
# start training...89
# hyper_params: (6.0, 215.0, 835.0)
# start training...90
# hyper_params: (7.0, 245.0, 85.0)
# start training...91
# hyper_params: (5.0, 175.0, 4680.0)
# start training...92
# hyper_params: (8.0, 875.0, 3180.0)
# start training...93
# hyper_params: (6.0, 585.0, 1795.0)
# start training...94
# hyper_params: (6.0, 825.0, 4175.0)
# start training...95
# hyper_params: (8.0, 705.0, 9075.0)
# start training...96
# hyper_params: (7.0, 360.0, 2435.0)
# start training...97
# hyper_params: (9.0, 640.0, 7545.0)
# start training...98
# hyper_params: (5.0, 560.0, 2915.0)
# start training...99
# hyper_params: (7.0, 605.0, 595.0)
# start training...100
# hyper_params: (6.0, 145.0, 5585.0)
# start training...101
# hyper_params: (8.0, 100.0, 8630.0)
# start training...102
# hyper_params: (9.0, 190.0, 6225.0)
# start training...103
# hyper_params: (7.0, 390.0, 3720.0)
# start training...104
# hyper_params: (5.0, 530.0, 1065.0)
# start training...105
# hyper_params: (8.0, 500.0, 2030.0)
# start training...106
# hyper_params: (6.0, 450.0, 1500.0)
# start training...107
# hyper_params: (7.0, 740.0, 400.0)
# start training...108
# hyper_params: (10.0, 330.0, 200.0)
# start training...109
# hyper_params: (6.0, 465.0, 5090.0)
# start training...110
# hyper_params: (8.0, 255.0, 1230.0)
# start training...111
# hyper_params: (7.0, 670.0, 885.0)
# start training...112
# hyper_params: (6.0, 290.0, 2760.0)
# start training...113
# hyper_params: (5.0, 35.0, 1705.0)
# start training...114
# hyper_params: (7.0, 950.0, 2280.0)
# start training...115
# hyper_params: (9.0, 310.0, 715.0)
# start training...116
# hyper_params: (8.0, 785.0, 3230.0)
# start training...117
# hyper_params: (7.0, 520.0, 2510.0)
# start training...118
# hyper_params: (5.0, 115.0, 9515.0)
# start training...119
# hyper_params: (6.0, 700.0, 7170.0)
# start training...120
# hyper_params: (10.0, 855.0, 40.0)
# start training...121
# hyper_params: (7.0, 435.0, 4225.0)
# start training...122
# hyper_params: (9.0, 350.0, 1360.0)
# start training...123
# hyper_params: (8.0, 410.0, 8130.0)
# start training...124
# hyper_params: (8.0, 755.0, 520.0)
# start training...125
# hyper_params: (6.0, 600.0, 3830.0)
# start training...126
# hyper_params: (7.0, 80.0, 985.0)
# start training...127
# hyper_params: (7.0, 80.0, 6910.0)
# start training...128
# hyper_params: (5.0, 160.0, 3500.0)
# start training...129
# hyper_params: (6.0, 235.0, 4570.0)
# start training...130
# hyper_params: (7.0, 50.0, 1990.0)
# start training...131
# hyper_params: (9.0, 210.0, 970.0)
# start training...132
# hyper_params: (8.0, 185.0, 1625.0)
# start training...133
# hyper_params: (6.0, 150.0, 190.0)
# start training...134
# hyper_params: (7.0, 545.0, 6085.0)
# start training...135
# hyper_params: (8.0, 125.0, 6565.0)
# start training...136
# hyper_params: (5.0, 100.0, 3015.0)
# start training...137
# hyper_params: (6.0, 70.0, 1170.0)
# start training...138
# hyper_params: (7.0, 650.0, 5590.0)
# start training...139
# hyper_params: (8.0, 370.0, 2795.0)
# start training...140
# hyper_params: (5.0, 570.0, 2230.0)
# start training...141
# hyper_params: (9.0, 275.0, 1840.0)
# start training...142
# hyper_params: (7.0, 715.0, 1470.0)
# start training...143
# hyper_params: (6.0, 820.0, 365.0)
# start training...144
# hyper_params: (7.0, 485.0, 660.0)
# start training...145
# hyper_params: (7.0, 35.0, 665.0)
# start training...146
# hyper_params: (7.0, 65.0, 645.0)
# start training...147
# hyper_params: (7.0, 45.0, 45.0)
# start training...148
# hyper_params: (8.0, 125.0, 715.0)
# start training...149
# hyper_params: (7.0, 90.0, 540.0)
# start training...150
# hyper_params: (8.0, 35.0, 1320.0)
# start training...151
# hyper_params: (7.0, 175.0, 2130.0)
# start training...152
# hyper_params: (7.0, 55.0, 40.0)
# start training...153
# hyper_params: (8.0, 135.0, 260.0)
# start training...154
# hyper_params: (7.0, 195.0, 800.0)
# start training...155
# hyper_params: (8.0, 215.0, 50.0)
# start training...156
# hyper_params: (7.0, 260.0, 1615.0)
# start training...157
# hyper_params: (8.0, 35.0, 1085.0)
# start training...158
# hyper_params: (7.0, 235.0, 2490.0)
# start training...159
# hyper_params: (7.0, 105.0, 1985.0)
# start training...160
# hyper_params: (8.0, 60.0, 3375.0)
# start training...161
# hyper_params: (8.0, 910.0, 1260.0)
# start training...162
# hyper_params: (7.0, 295.0, 895.0)
# start training...163
# hyper_params: (7.0, 170.0, 320.0)
# start training...164
# hyper_params: (8.0, 320.0, 7480.0)
# start training...165
# hyper_params: (7.0, 150.0, 1710.0)
# start training...166
# hyper_params: (7.0, 115.0, 45.0)
# start training...167
# hyper_params: (8.0, 85.0, 2620.0)
# start training...168
# hyper_params: (7.0, 55.0, 440.0)
# start training...169
# hyper_params: (6.0, 195.0, 1430.0)
# start training...170
# hyper_params: (7.0, 1015.0, 505.0)
# start training...171
# hyper_params: (6.0, 135.0, 2310.0)
# start training...172
# hyper_params: (7.0, 345.0, 1880.0)
# start training...173
# hyper_params: (6.0, 235.0, 35.0)
# start training...174
# hyper_params: (7.0, 35.0, 9950.0)
# start training...175
# hyper_params: (7.0, 265.0, 1065.0)
# start training...176
# hyper_params: (6.0, 160.0, 4870.0)
# start training...177
# hyper_params: (7.0, 60.0, 4330.0)
# start training...178
# hyper_params: (7.0, 965.0, 725.0)
# start training...179
# hyper_params: (6.0, 105.0, 3935.0)
# start training...180
# hyper_params: (7.0, 305.0, 250.0)
# start training...181
# hyper_params: (7.0, 250.0, 2965.0)
# start training...182
# hyper_params: (6.0, 375.0, 3650.0)
# start training...183
# hyper_params: (7.0, 215.0, 1530.0)
# start training...184
# hyper_params: (6.0, 80.0, 3220.0)
# start training...185
# hyper_params: (7.0, 490.0, 925.0)
# start training...186
# hyper_params: (7.0, 175.0, 8530.0)
# start training...187
# hyper_params: (6.0, 410.0, 415.0)
# start training...188
# hyper_params: (8.0, 50.0, 2140.0)
# start training...189
# hyper_params: (7.0, 135.0, 5120.0)
# start training...190
# hyper_params: (6.0, 200.0, 8205.0)
# start training...191
# hyper_params: (7.0, 870.0, 9400.0)
# start training...192
# hyper_params: (8.0, 95.0, 5405.0)
# start training...193
# hyper_params: (7.0, 630.0, 1180.0)
# start training...194
# hyper_params: (6.0, 115.0, 590.0)
# start training...195
# hyper_params: (7.0, 280.0, 1725.0)
# start training...196
# hyper_params: (8.0, 845.0, 2725.0)
# start training...197
# hyper_params: (7.0, 150.0, 220.0)
# start training...198
# hyper_params: (8.0, 330.0, 2390.0)
# start training...199
# hyper_params: (7.0, 35.0, 825.0)
# start training...200
# hyper_params: (6.0, 65.0, 1305.0)
# start training...201
# hyper_params: (7.0, 35.0, 1935.0)
# start training...202
# hyper_params: (6.0, 85.0, 50.0)
# start training...203
# hyper_params: (7.0, 185.0, 990.0)
# start training...204
# hyper_params: (8.0, 125.0, 765.0)
# start training...205
# hyper_params: (6.0, 55.0, 5970.0)
# start training...206
# hyper_params: (7.0, 220.0, 1585.0)
# start training...207
# hyper_params: (7.0, 75.0, 4660.0)
# start training...208
# hyper_params: (8.0, 160.0, 405.0)
# start training...209
# hyper_params: (7.0, 95.0, 3085.0)
# start training...210
# hyper_params: (6.0, 30.0, 1415.0)
# start training...211
# hyper_params: (8.0, 120.0, 6580.0)
# start training...212
# hyper_params: (7.0, 145.0, 2485.0)
# start training...213
# hyper_params: (6.0, 240.0, 1175.0)
# start training...214
# hyper_params: (7.0, 35.0, 2095.0)
# start training...215
# hyper_params: (8.0, 175.0, 1830.0)
# start training...216
# hyper_params: (7.0, 105.0, 2845.0)
# start training...217
# hyper_params: (6.0, 50.0, 60.0)
# start training...218
# hyper_params: (8.0, 195.0, 830.0)
# start training...219
# hyper_params: (7.0, 265.0, 3435.0)
# start training...220
# hyper_params: (5.0, 75.0, 250.0)
# start training...221
# hyper_params: (7.0, 225.0, 570.0)
# start training...222
# hyper_params: (6.0, 300.0, 2255.0)
# start training...223
# hyper_params: (7.0, 130.0, 4010.0)
# start training...224
# hyper_params: (8.0, 35.0, 1030.0)
# start training...225
# hyper_params: (7.0, 205.0, 1445.0)
# start training...226
# hyper_params: (6.0, 65.0, 7350.0)
# start training...227
# hyper_params: (7.0, 155.0, 1735.0)
# start training...228
# hyper_params: (8.0, 100.0, 435.0)
# start training...229
# hyper_params: (7.0, 390.0, 1230.0)
# start training...230
# hyper_params: (6.0, 360.0, 6975.0)
# start training...231
# hyper_params: (9.0, 180.0, 2640.0)
# start training...232
# hyper_params: (7.0, 30.0, 50.0)
# start training...233
# hyper_params: (8.0, 255.0, 140.0)
# start training...234
# hyper_params: (7.0, 315.0, 8800.0)
# start training...235
# hyper_params: (6.0, 55.0, 275.0)
# start training...236
# hyper_params: (8.0, 140.0, 665.0)
# start training...237
# hyper_params: (7.0, 80.0, 80.0)
# start training...238
# hyper_params: (6.0, 285.0, 480.0)
# start training...239
# hyper_params: (8.0, 110.0, 7840.0)
# start training...240
# hyper_params: (5.0, 160.0, 1615.0)
# start training...241
# hyper_params: (7.0, 460.0, 975.0)
# start training...242
# hyper_params: (7.0, 230.0, 1300.0)
# start training...243
# hyper_params: (7.0, 90.0, 45.0)
# start training...244
# hyper_params: (5.0, 205.0, 3790.0)
# start training...245
# hyper_params: (10.0, 120.0, 2135.0)
# start training...246
# hyper_params: (8.0, 35.0, 1915.0)
# start training...247
# hyper_params: (6.0, 60.0, 765.0)
# start training...248
# hyper_params: (7.0, 430.0, 3290.0)
# start training...249
# hyper_params: (6.0, 30.0, 4285.0)
# start training...250
# hyper_params: (7.0, 180.0, 6345.0)
# start training...251
# hyper_params: (8.0, 335.0, 355.0)
# start training...252
# hyper_params: (7.0, 920.0, 2340.0)
# start training...253
# hyper_params: (8.0, 135.0, 635.0)
# start training...254
# hyper_params: (6.0, 250.0, 1055.0)
# start training...255
# hyper_params: (7.0, 90.0, 5685.0)
# start training...256
# hyper_params: (7.0, 60.0, 1465.0)
# start training...257
# hyper_params: (7.0, 45.0, 890.0)
# start training...258
# hyper_params: (7.0, 35.0, 225.0)
# start training...259
# hyper_params: (7.0, 105.0, 460.0)
# start training...260
# hyper_params: (7.0, 80.0, 1130.0)
# start training...261
# hyper_params: (7.0, 140.0, 55.0)
# start training...262
# hyper_params: (7.0, 165.0, 905.0)
# start training...263
# hyper_params: (7.0, 35.0, 700.0)
# start training...264
# hyper_params: (7.0, 70.0, 1675.0)
# start training...265
# hyper_params: (7.0, 30.0, 250.0)
# start training...266
# hyper_params: (7.0, 120.0, 1320.0)
# start training...267
# hyper_params: (7.0, 100.0, 1830.0)
# start training...268
# hyper_params: (7.0, 215.0, 845.0)
# start training...269
# hyper_params: (7.0, 50.0, 560.0)
# start training...270
# hyper_params: (8.0, 185.0, 50.0)
# start training...271
# hyper_params: (6.0, 145.0, 510.0)
# start training...272
# hyper_params: (7.0, 55.0, 1195.0)
# start training...273
# hyper_params: (6.0, 75.0, 1535.0)
# start training...274
# hyper_params: (7.0, 115.0, 365.0)
# start training...275
# hyper_params: (8.0, 160.0, 2020.0)
# start training...276
# hyper_params: (7.0, 205.0, 565.0)
# start training...277
# hyper_params: (6.0, 90.0, 1080.0)
# start training...278
# hyper_params: (7.0, 275.0, 2535.0)
# start training...279
# hyper_params: (8.0, 130.0, 60.0)
# start training...280
# hyper_params: (7.0, 60.0, 250.0)
# start training...281
# hyper_params: (6.0, 235.0, 1335.0)
# start training...282
# hyper_params: (7.0, 170.0, 705.0)
# start training...283
# hyper_params: (8.0, 95.0, 35.0)
# start training...284
# hyper_params: (7.0, 50.0, 2965.0)
# start training...285
# hyper_params: (6.0, 195.0, 470.0)
# start training...286
# hyper_params: (7.0, 125.0, 1675.0)
# start training...287
# hyper_params: (8.0, 150.0, 940.0)
# start training...288
# hyper_params: (7.0, 35.0, 2155.0)
# start training...289
# hyper_params: (7.0, 75.0, 1485.0)
# start training...290
# hyper_params: (6.0, 890.0, 8320.0)
# start training...291
# hyper_params: (8.0, 110.0, 2790.0)
# start training...292
# hyper_params: (7.0, 305.0, 1155.0)
# start training...293
# hyper_params: (7.0, 50.0, 250.0)
# start training...294
# hyper_params: (6.0, 30.0, 1865.0)
# start training...295
# hyper_params: (8.0, 225.0, 40.0)
# start training...296
# hyper_params: (7.0, 180.0, 650.0)
# start training...297
# hyper_params: (7.0, 260.0, 2305.0)
# start training...298
# hyper_params: (8.0, 145.0, 9310.0)
# start training...299
# hyper_params: (7.0, 80.0, 5255.0)
# start training...300
# hyper_params: (6.0, 115.0, 815.0)
# start training...301
# hyper_params: (7.0, 95.0, 4920.0)
# start training...302
# hyper_params: (6.0, 195.0, 6760.0)
# start training...303
# hyper_params: (7.0, 60.0, 395.0)
# start training...304
# hyper_params: (8.0, 160.0, 4475.0)
# start training...305
# hyper_params: (7.0, 280.0, 1395.0)
# start training...306
# hyper_params: (7.0, 30.0, 1015.0)
# start training...307
# hyper_params: (8.0, 245.0, 1980.0)
# start training...308
# hyper_params: (6.0, 135.0, 9645.0)
# start training...309
# hyper_params: (7.0, 70.0, 3545.0)
# start training...310
# hyper_params: (7.0, 805.0, 3115.0)
# start training...311
# hyper_params: (6.0, 210.0, 560.0)
# start training...312
# hyper_params: (8.0, 990.0, 1680.0)
# start training...313
# hyper_params: (7.0, 740.0, 270.0)
# start training...314
# hyper_params: (7.0, 675.0, 755.0)
# start training...315
# hyper_params: (6.0, 105.0, 2615.0)
# start training...316
# hyper_params: (7.0, 165.0, 1125.0)
# start training...317
# hyper_params: (8.0, 340.0, 1240.0)
# start training...318
# hyper_params: (7.0, 765.0, 165.0)
# start training...319
# hyper_params: (6.0, 50.0, 2400.0)
# start training...320
# hyper_params: (7.0, 85.0, 1475.0)
# start training...321
# hyper_params: (9.0, 510.0, 50.0)
# start training...322
# hyper_params: (10.0, 30.0, 925.0)
# start training...323
# hyper_params: (8.0, 400.0, 1805.0)
# start training...324
# hyper_params: (6.0, 130.0, 600.0)
# start training...325
# hyper_params: (7.0, 185.0, 40.0)
# start training...326
# hyper_params: (7.0, 225.0, 405.0)
# start training...327
# hyper_params: (7.0, 105.0, 2150.0)
# start training...328
# hyper_params: (8.0, 70.0, 1575.0)
# start training...329
# hyper_params: (6.0, 375.0, 1355.0)
# start training...330
# hyper_params: (7.0, 295.0, 35.0)
# start training...331
# hyper_params: (8.0, 540.0, 815.0)
# start training...332
# hyper_params: (7.0, 170.0, 360.0)
# start training...333
# hyper_params: (7.0, 45.0, 1040.0)
# start training...334
# hyper_params: (5.0, 115.0, 595.0)
# start training...335
# hyper_params: (8.0, 940.0, 4140.0)
# start training...336
# hyper_params: (6.0, 140.0, 1965.0)
# start training...337
# hyper_params: (7.0, 325.0, 2810.0)
# start training...338
# hyper_params: (7.0, 30.0, 7635.0)
# start training...339
# hyper_params: (7.0, 245.0, 1210.0)
# start training...340
# hyper_params: (8.0, 85.0, 2420.0)
# start training...341
# hyper_params: (6.0, 205.0, 1760.0)
# start training...342
# hyper_params: (7.0, 610.0, 255.0)
# start training...343
# hyper_params: (6.0, 445.0, 840.0)
# start training...344
# hyper_params: (7.0, 75.0, 450.0)
# start training...345
# hyper_params: (8.0, 265.0, 1545.0)
# start training...346
# hyper_params: (7.0, 60.0, 3200.0)
# start training...347
# hyper_params: (6.0, 580.0, 5855.0)
# start training...348
# hyper_params: (9.0, 120.0, 4700.0)
# start training...349
# hyper_params: (7.0, 30.0, 615.0)
# start training...350
# hyper_params: (7.0, 150.0, 2085.0)
# start training...351
# hyper_params: (8.0, 175.0, 2610.0)
# start training...352
# hyper_params: (6.0, 95.0, 1255.0)
# start training...353
# hyper_params: (7.0, 50.0, 3620.0)
# start training...354
# hyper_params: (7.0, 220.0, 1000.0)
# start training...355
# hyper_params: (8.0, 150.0, 2210.0)
# start training...356
# hyper_params: (7.0, 120.0, 5505.0)
# start training...357
# hyper_params: (6.0, 355.0, 3000.0)
# start training...358
# hyper_params: (8.0, 50.0, 7260.0)
# start training...359
# hyper_params: (7.0, 100.0, 3810.0)
# start training...360
# hyper_params: (7.0, 195.0, 710.0)
# start training...361
# hyper_params: (7.0, 70.0, 3380.0)
# start training...362
# hyper_params: (6.0, 305.0, 1900.0)
# start training...363
# hyper_params: (8.0, 275.0, 1395.0)
# start training...364
# hyper_params: (5.0, 35.0, 1680.0)
# start training...365
# hyper_params: (7.0, 655.0, 580.0)
# start training...366
# hyper_params: (7.0, 420.0, 1115.0)
# start training...367
# hyper_params: (6.0, 240.0, 285.0)
# start training...368
# hyper_params: (7.0, 175.0, 2400.0)
# start training...369
# hyper_params: (8.0, 85.0, 6410.0)
# start training...370
# hyper_params: (7.0, 130.0, 2785.0)
# start training...371
# hyper_params: (8.0, 155.0, 940.0)
# start training...372
# hyper_params: (6.0, 60.0, 1440.0)
# start training...373
# hyper_params: (7.0, 470.0, 510.0)
# start training...374
# hyper_params: (7.0, 215.0, 200.0)
# start training...375
# hyper_params: (7.0, 105.0, 6070.0)
# start training...376
# hyper_params: (8.0, 35.0, 710.0)
# start training...377
# hyper_params: (9.0, 135.0, 2025.0)
# start training...378
# hyper_params: (9.0, 965.0, 1785.0)
# start training...379
# hyper_params: (9.0, 1020.0, 2585.0)
# start training...380
# hyper_params: (8.0, 195.0, 1555.0)
# start training...381
# hyper_params: (9.0, 40.0, 2220.0)
# start training...382
# hyper_params: (9.0, 80.0, 1230.0)
# start training...383
# hyper_params: (9.0, 160.0, 810.0)
# start training...384
# hyper_params: (8.0, 35.0, 2995.0)
# start training...385
# hyper_params: (10.0, 95.0, 1015.0)
# start training...386
# hyper_params: (8.0, 255.0, 1950.0)
# start training...387
# hyper_params: (8.0, 115.0, 685.0)
# start training...388
# hyper_params: (8.0, 70.0, 1345.0)
# start training...389
# hyper_params: (9.0, 185.0, 2330.0)
# start training...390
# hyper_params: (8.0, 290.0, 35.0)
# start training...391
# hyper_params: (8.0, 140.0, 9005.0)
# start training...392
# hyper_params: (8.0, 720.0, 1720.0)
# start training...393
# hyper_params: (8.0, 50.0, 395.0)
# start training...394
# hyper_params: (9.0, 235.0, 5050.0)
# start training...395
# hyper_params: (9.0, 695.0, 3320.0)
# start training...396
# hyper_params: (9.0, 50.0, 1090.0)
# start training...397
# hyper_params: (9.0, 560.0, 1570.0)
# start training...398
# hyper_params: (8.0, 35.0, 35.0)
# start training...399
# hyper_params: (8.0, 85.0, 350.0)
# start training...400
# hyper_params: (8.0, 65.0, 550.0)
# start training...401
# hyper_params: (8.0, 65.0, 770.0)
# start training...402
# hyper_params: (8.0, 35.0, 615.0)
# start training...403
# hyper_params: (9.0, 105.0, 605.0)
# start training...404
# hyper_params: (8.0, 125.0, 430.0)
# start training...405
# hyper_params: (8.0, 35.0, 955.0)
# start training...406
# hyper_params: (9.0, 90.0, 185.0)
# start training...407
# hyper_params: (8.0, 65.0, 830.0)
# start training...408
# hyper_params: (8.0, 145.0, 1235.0)
# start training...409
# hyper_params: (8.0, 35.0, 360.0)
# start training...410
# hyper_params: (9.0, 30.0, 225.0)
# start training...411
# hyper_params: (8.0, 120.0, 560.0)
# start training...412
# hyper_params: (8.0, 85.0, 1270.0)
# start training...413
# hyper_params: (8.0, 70.0, 1065.0)
# start training...414
# hyper_params: (8.0, 55.0, 1425.0)
# start training...415
# hyper_params: (9.0, 35.0, 740.0)
# start training...416
# hyper_params: (10.0, 100.0, 815.0)
# start training...417
# hyper_params: (10.0, 160.0, 45.0)
# start training...418
# hyper_params: (10.0, 115.0, 1615.0)
# start training...419
# hyper_params: (10.0, 175.0, 1910.0)
# start training...420
# hyper_params: (10.0, 135.0, 1120.0)
# start training...421
# hyper_params: (9.0, 785.0, 235.0)
# start training...422
# hyper_params: (9.0, 80.0, 895.0)
# start training...423
# hyper_params: (10.0, 30.0, 1370.0)
# start training...424
# hyper_params: (9.0, 210.0, 50.0)
# start training...425
# hyper_params: (9.0, 50.0, 450.0)
# start training...426
# hyper_params: (10.0, 105.0, 1745.0)
# start training...427
# hyper_params: (9.0, 155.0, 630.0)
# start training...428
# hyper_params: (9.0, 190.0, 960.0)
# start training...429
# hyper_params: (9.0, 70.0, 2220.0)
# start training...430
# hyper_params: (9.0, 130.0, 45.0)
# start training...431
# hyper_params: (10.0, 35.0, 1525.0)
# start training...432
# hyper_params: (10.0, 90.0, 355.0)
# start training...433
# hyper_params: (9.0, 830.0, 1200.0)
# start training...434
# hyper_params: (9.0, 170.0, 7955.0)
# start training...435
# hyper_params: (9.0, 55.0, 2070.0)
# start training...436
# hyper_params: (10.0, 140.0, 770.0)
# start training...437
# hyper_params: (8.0, 110.0, 2615.0)
# start training...438
# hyper_params: (8.0, 85.0, 1850.0)
# start training...439
# hyper_params: (9.0, 35.0, 235.0)
# start training...440
# hyper_params: (8.0, 195.0, 540.0)
# start training...441
# hyper_params: (8.0, 70.0, 1085.0)
# start training...442
# hyper_params: (9.0, 220.0, 1330.0)
# start training...443
# hyper_params: (8.0, 35.0, 715.0)
# start training...444
# hyper_params: (8.0, 110.0, 1595.0)
# start training...445
# hyper_params: (9.0, 150.0, 2430.0)
# start training...446
# hyper_params: (10.0, 125.0, 490.0)
# start training...447
# hyper_params: (8.0, 630.0, 920.0)
# start training...448
# hyper_params: (8.0, 65.0, 55.0)
# start training...449
# hyper_params: (8.0, 95.0, 295.0)
# start training...450
# hyper_params: (9.0, 50.0, 2005.0)
# start training...451
# hyper_params: (8.0, 175.0, 8715.0)
# start training...452
# hyper_params: (8.0, 520.0, 1485.0)
# start training...453
# hyper_params: (8.0, 35.0, 705.0)
# start training...454
# hyper_params: (9.0, 265.0, 1190.0)
# start training...455
# hyper_params: (8.0, 80.0, 1790.0)
# start training...456
# hyper_params: (10.0, 130.0, 940.0)
# start training...457
# hyper_params: (8.0, 160.0, 2785.0)
# start training...458
# hyper_params: (9.0, 495.0, 45.0)
# start training...459
# hyper_params: (8.0, 315.0, 400.0)
# start training...460
# hyper_params: (10.0, 55.0, 1410.0)
# start training...461
# hyper_params: (8.0, 100.0, 2305.0)
# start training...462
# hyper_params: (9.0, 230.0, 225.0)
# start training...463
# hyper_params: (8.0, 205.0, 1130.0)
# start training...464
# hyper_params: (8.0, 865.0, 1715.0)
# start training...465
# hyper_params: (9.0, 35.0, 750.0)
# start training...466
# hyper_params: (10.0, 75.0, 860.0)
# start training...467
# hyper_params: (10.0, 115.0, 2140.0)
# start training...468
# hyper_params: (9.0, 55.0, 9850.0)
# start training...469
# hyper_params: (10.0, 385.0, 45.0)
# start training...470
# hyper_params: (9.0, 140.0, 7075.0)
# start training...471
# hyper_params: (9.0, 175.0, 485.0)
# start training...472
# hyper_params: (10.0, 35.0, 1290.0)
# start training...473
# hyper_params: (10.0, 95.0, 1050.0)
# start training...474
# hyper_params: (9.0, 155.0, 35.0)
# start training...475
# hyper_params: (9.0, 245.0, 1900.0)
# start training...476
# hyper_params: (9.0, 185.0, 2510.0)
# start training...477
# hyper_params: (10.0, 70.0, 1610.0)
# start training...478
# hyper_params: (9.0, 115.0, 575.0)
# start training...479
# hyper_params: (9.0, 340.0, 3905.0)
# start training...480
# hyper_params: (9.0, 35.0, 3105.0)
# start training...481
# hyper_params: (10.0, 205.0, 1385.0)
# start training...482
# hyper_params: (9.0, 130.0, 4420.0)
# start training...483
# hyper_params: (10.0, 90.0, 195.0)
# start training...484
# hyper_params: (9.0, 30.0, 820.0)
# start training...485
# hyper_params: (10.0, 280.0, 265.0)
# start training...486
# hyper_params: (9.0, 590.0, 425.0)
# start training...487
# hyper_params: (9.0, 55.0, 1065.0)
# start training...488
# hyper_params: (9.0, 150.0, 2105.0)
# start training...489
# hyper_params: (10.0, 75.0, 605.0)
# start training...490
# hyper_params: (10.0, 225.0, 2880.0)
# start training...491
# hyper_params: (9.0, 745.0, 8415.0)
# start training...492
# hyper_params: (9.0, 110.0, 1575.0)
# start training...493
# hyper_params: (9.0, 170.0, 1305.0)
# start training...494
# hyper_params: (9.0, 50.0, 1800.0)
# start training...495
# hyper_params: (10.0, 90.0, 705.0)
# start training...496
# hyper_params: (9.0, 145.0, 35.0)
# start training...497
# hyper_params: (10.0, 70.0, 945.0)
# start training...498
# hyper_params: (9.0, 360.0, 305.0)
# start training...499
# hyper_params: (9.0, 125.0, 4140.0)
# start training...500
# hyper_params: (9.0, 195.0, 1185.0)
# start training...501
# hyper_params: (10.0, 905.0, 2315.0)
# start training...502
# hyper_params: (8.0, 445.0, 495.0)
# start training...503
# hyper_params: (9.0, 255.0, 3430.0)
# start training...504
# hyper_params: (8.0, 105.0, 6840.0)
# start training...505
# hyper_params: (10.0, 35.0, 2685.0)
# start training...506
# hyper_params: (8.0, 55.0, 1540.0)
# start training...507
# hyper_params: (9.0, 165.0, 5315.0)
# start training...508
# hyper_params: (8.0, 985.0, 820.0)
# start training...509
# hyper_params: (9.0, 405.0, 1995.0)
# start training...510
# hyper_params: (10.0, 85.0, 1000.0)
# start training...511
# hyper_params: (8.0, 35.0, 50.0)
# start training...512
# hyper_params: (9.0, 215.0, 3615.0)
# start training...513
# hyper_params: (8.0, 135.0, 330.0)
# start training...514
# hyper_params: (10.0, 65.0, 9220.0)
# start training...515
# hyper_params: (9.0, 100.0, 1400.0)
# start training...516
# hyper_params: (8.0, 120.0, 1700.0)
# start training...517
# hyper_params: (8.0, 190.0, 4770.0)
# start training...518
# hyper_params: (9.0, 35.0, 2455.0)
# start training...519
# hyper_params: (8.0, 155.0, 575.0)
# start training...520
# hyper_params: (9.0, 235.0, 2155.0)
# start training...521
# hyper_params: (10.0, 30.0, 35.0)
# start training...522
# hyper_params: (8.0, 75.0, 1160.0)
# start training...523
# hyper_params: (9.0, 50.0, 870.0)
# start training...524
# hyper_params: (8.0, 285.0, 690.0)
# start training...525
# hyper_params: (7.0, 180.0, 1835.0)
# start training...526
# hyper_params: (9.0, 95.0, 205.0)
# start training...527
# hyper_params: (8.0, 540.0, 1275.0)
# start training...528
# hyper_params: (10.0, 125.0, 405.0)
# start training...529
# hyper_params: (7.0, 205.0, 3160.0)
# start training...530
# hyper_params: (8.0, 320.0, 1580.0)
# start training...531
# hyper_params: (9.0, 480.0, 40.0)
# start training...532
# hyper_params: (7.0, 55.0, 690.0)
# start training...533
# hyper_params: (8.0, 145.0, 1035.0)
# start training...534
# hyper_params: (9.0, 80.0, 1430.0)
# start training...535
# hyper_params: (7.0, 260.0, 1970.0)
# start training...536
# hyper_params: (10.0, 165.0, 455.0)
# start training...537
# hyper_params: (8.0, 100.0, 2895.0)
# start training...538
# hyper_params: (9.0, 65.0, 230.0)
# start training...539
# hyper_params: (7.0, 670.0, 870.0)
# start training...540
# hyper_params: (8.0, 110.0, 2275.0)
# start training...541
# hyper_params: (7.0, 135.0, 7460.0)
# start training...542
# hyper_params: (9.0, 50.0, 6175.0)
# start training...543
# hyper_params: (10.0, 235.0, 1170.0)
# start training...544
# hyper_params: (8.0, 80.0, 1650.0)
# start training...545
# hyper_params: (8.0, 190.0, 615.0)
# start training...546
# hyper_params: (7.0, 115.0, 2590.0)
# start training...547
# hyper_params: (9.0, 35.0, 1365.0)
# start training...548
# hyper_params: (7.0, 35.0, 340.0)
# start training...549
# hyper_params: (8.0, 160.0, 815.0)
# start training...550
# hyper_params: (8.0, 810.0, 990.0)
# start training...551
# hyper_params: (7.0, 300.0, 5710.0)
# start training...552
# hyper_params: (10.0, 615.0, 50.0)
# start training...553
# hyper_params: (9.0, 30.0, 8050.0)
# start training...554
# hyper_params: (9.0, 90.0, 1890.0)
# start training...555
# hyper_params: (7.0, 425.0, 220.0)
# start training...556
# hyper_params: (8.0, 215.0, 1175.0)
# start training...557
# hyper_params: (8.0, 30.0, 6490.0)
# start training...558
# hyper_params: (10.0, 135.0, 525.0)
# start training...559
# hyper_params: (7.0, 75.0, 1720.0)
# start training...560
# hyper_params: (9.0, 175.0, 2455.0)
# start training...561
# hyper_params: (8.0, 55.0, 1460.0)
# start training...562
# hyper_params: (7.0, 110.0, 660.0)
# start training...563
# hyper_params: (9.0, 265.0, 980.0)
# start training...564
# hyper_params: (8.0, 30.0, 2055.0)
# start training...565
# hyper_params: (7.0, 145.0, 45.0)
# start training...566
# hyper_params: (10.0, 770.0, 405.0)
# start training...567
# hyper_params: (9.0, 70.0, 2690.0)
# start training...568
# hyper_params: (7.0, 95.0, 765.0)
# start training...569
# hyper_params: (8.0, 645.0, 1315.0)
# start training...570
# hyper_params: (9.0, 850.0, 210.0)
# start training...571
# hyper_params: (8.0, 125.0, 2240.0)
# start training...572
# hyper_params: (10.0, 185.0, 9995.0)
# start training...573
# hyper_params: (7.0, 55.0, 1160.0)
# start training...574
# hyper_params: (8.0, 230.0, 40.0)
# start training...575
# hyper_params: (9.0, 150.0, 1745.0)
# start training...576
# hyper_params: (8.0, 50.0, 720.0)
# start training...577
# hyper_params: (8.0, 35.0, 555.0)
# start training...578
# hyper_params: (8.0, 65.0, 495.0)
# start training...579
# hyper_params: (8.0, 85.0, 455.0)
# start training...580
# hyper_params: (8.0, 70.0, 970.0)
# start training...581
# hyper_params: (8.0, 105.0, 225.0)
# start training...582
# hyper_params: (8.0, 55.0, 480.0)
# start training...583
# hyper_params: (8.0, 130.0, 785.0)
# start training...584
# hyper_params: (8.0, 95.0, 45.0)
# start training...585
# hyper_params: (8.0, 65.0, 500.0)
# start training...586
# hyper_params: (8.0, 120.0, 1150.0)
# start training...587
# hyper_params: (8.0, 85.0, 1500.0)
# start training...588
# hyper_params: (8.0, 60.0, 900.0)
# start training...589
# hyper_params: (8.0, 45.0, 505.0)
# start training...590
# hyper_params: (8.0, 165.0, 295.0)
# start training...591
# hyper_params: (8.0, 30.0, 35.0)
# start training...592
# hyper_params: (8.0, 110.0, 1250.0)
# start training...593
# hyper_params: (8.0, 140.0, 625.0)
# start training...594
# hyper_params: (8.0, 85.0, 990.0)
# start training...595
# hyper_params: (8.0, 50.0, 35.0)
# start training...596
# hyper_params: (8.0, 105.0, 820.0)
# start training...597
# hyper_params: (8.0, 70.0, 1510.0)
# start training...598
# hyper_params: (8.0, 200.0, 235.0)
# start training...599
# hyper_params: (8.0, 160.0, 1305.0)
# start training...600
# hyper_params: (9.0, 35.0, 1030.0)
# start training...601
# hyper_params: (8.0, 135.0, 1090.0)
# start training...602
# hyper_params: (9.0, 120.0, 355.0)
# start training...603
# hyper_params: (8.0, 30.0, 615.0)
# start training...604
# hyper_params: (8.0, 95.0, 1870.0)
# start training...605
# hyper_params: (9.0, 55.0, 1005.0)
# start training...606
# hyper_params: (9.0, 75.0, 1610.0)
# start training...607
# hyper_params: (8.0, 185.0, 530.0)
# start training...608
# hyper_params: (8.0, 150.0, 1360.0)
# start training...609
# hyper_params: (8.0, 110.0, 835.0)
# start training...610
# hyper_params: (9.0, 50.0, 205.0)
# start training...611
# hyper_params: (8.0, 85.0, 1150.0)
# start training...612
# hyper_params: (8.0, 170.0, 9600.0)
# start training...613
# hyper_params: (9.0, 205.0, 405.0)
# start training...614
# hyper_params: (9.0, 65.0, 1715.0)
# start training...615
# hyper_params: (8.0, 120.0, 2055.0)
# start training...616
# hyper_params: (8.0, 95.0, 1405.0)
# start training...617
# hyper_params: (9.0, 155.0, 40.0)
# start training...618
# hyper_params: (8.0, 50.0, 920.0)
# start training...619
# hyper_params: (9.0, 30.0, 625.0)
# start training...620
# hyper_params: (9.0, 80.0, 1580.0)
# start training...621
# hyper_params: (9.0, 35.0, 705.0)
# start training...622
# hyper_params: (10.0, 35.0, 1235.0)
# start training...623
# hyper_params: (9.0, 125.0, 1910.0)
# start training...624
# hyper_params: (9.0, 35.0, 200.0)
# start training...625
# hyper_params: (9.0, 100.0, 1030.0)
# start training...626
# hyper_params: (10.0, 80.0, 720.0)
# start training...627
# hyper_params: (9.0, 140.0, 40.0)
# start training...628
# hyper_params: (9.0, 30.0, 1475.0)
# start training...629
# hyper_params: (9.0, 60.0, 2135.0)
# start training...630
# hyper_params: (10.0, 170.0, 550.0)
# start training...631
# hyper_params: (9.0, 245.0, 290.0)
# start training...632
# hyper_params: (9.0, 105.0, 7730.0)
# start training...633
# hyper_params: (9.0, 710.0, 1770.0)
# start training...634
# hyper_params: (10.0, 220.0, 810.0)
# start training...635
# hyper_params: (9.0, 930.0, 1255.0)
# start training...636
# hyper_params: (10.0, 70.0, 2370.0)
# start training...637
# hyper_params: (9.0, 185.0, 1045.0)
# start training...638
# hyper_params: (9.0, 130.0, 425.0)
# start training...639
# hyper_params: (10.0, 35.0, 195.0)
# start training...640
# hyper_params: (9.0, 70.0, 625.0)
# start training...641
# hyper_params: (9.0, 145.0, 45.0)
# start training...642
# hyper_params: (9.0, 95.0, 1500.0)
# start training...643
# hyper_params: (10.0, 565.0, 960.0)
# start training...644
# hyper_params: (9.0, 120.0, 1305.0)
# start training...645
# hyper_params: (10.0, 30.0, 395.0)
# start training...646
# hyper_params: (9.0, 50.0, 1965.0)
# start training...647
# hyper_params: (9.0, 200.0, 1750.0)
# start training...648
# hyper_params: (10.0, 80.0, 825.0)
# start training...649
# hyper_params: (9.0, 165.0, 5030.0)
# start training...650
# hyper_params: (10.0, 110.0, 595.0)
# start training...651
# hyper_params: (9.0, 55.0, 215.0)
# start training...652
# hyper_params: (9.0, 95.0, 1140.0)
# start training...653
# hyper_params: (9.0, 35.0, 2225.0)
# start training...654
# hyper_params: (10.0, 135.0, 865.0)
# start training...655
# hyper_params: (9.0, 370.0, 1570.0)
# start training...656
# hyper_params: (9.0, 880.0, 1350.0)
# start training...657
# hyper_params: (10.0, 505.0, 5890.0)
# start training...658
# hyper_params: (9.0, 1005.0, 8840.0)
# start training...659
# hyper_params: (9.0, 70.0, 2510.0)
# start training...660
# hyper_params: (9.0, 185.0, 390.0)
# start training...661
# hyper_params: (10.0, 280.0, 680.0)
# start training...662
# hyper_params: (9.0, 50.0, 1095.0)
# start training...663
# hyper_params: (10.0, 30.0, 170.0)
# start training...664
# hyper_params: (9.0, 115.0, 2935.0)
# start training...665
# hyper_params: (9.0, 215.0, 4505.0)
# start training...666
# hyper_params: (8.0, 150.0, 1650.0)
# start training...667
# hyper_params: (10.0, 85.0, 2095.0)
# start training...668
# hyper_params: (9.0, 30.0, 490.0)
# start training...669
# hyper_params: (9.0, 335.0, 1875.0)
# start training...670
# hyper_params: (8.0, 70.0, 930.0)
# start training...671
# hyper_params: (8.0, 455.0, 1195.0)
# start training...672
# hyper_params: (8.0, 160.0, 1420.0)
# start training...673
# hyper_params: (10.0, 130.0, 715.0)
# start training...674
# hyper_params: (9.0, 105.0, 3285.0)
# start training...675
# hyper_params: (8.0, 60.0, 300.0)
# start training...676
# hyper_params: (9.0, 255.0, 6670.0)
# start training...677
# hyper_params: (9.0, 180.0, 65.0)
# start training...678
# hyper_params: (8.0, 85.0, 60.0)
# start training...679
# hyper_params: (10.0, 45.0, 495.0)
# start training...680
# hyper_params: (9.0, 50.0, 5495.0)
# start training...681
# hyper_params: (10.0, 115.0, 1080.0)
# start training...682
# hyper_params: (10.0, 45.0, 3695.0)
# start training...683
# hyper_params: (10.0, 90.0, 790.0)
# start training...684
# hyper_params: (10.0, 150.0, 40.0)
# start training...685
# hyper_params: (10.0, 35.0, 1665.0)
# start training...686
# hyper_params: (10.0, 35.0, 1345.0)
# start training...687
# hyper_params: (10.0, 135.0, 2680.0)
# start training...688
# hyper_params: (10.0, 225.0, 2375.0)
# start training...689
# hyper_params: (10.0, 65.0, 380.0)
# start training...690
# hyper_params: (10.0, 100.0, 950.0)
# start training...691
# hyper_params: (10.0, 35.0, 560.0)
# start training...692
# hyper_params: (10.0, 200.0, 575.0)
# start training...693
# hyper_params: (10.0, 85.0, 250.0)
# start training...694
# hyper_params: (10.0, 525.0, 685.0)
# start training...695
# hyper_params: (10.0, 120.0, 55.0)
# start training...696
# hyper_params: (10.0, 165.0, 355.0)
# start training...697
# hyper_params: (10.0, 50.0, 1205.0)
# start training...698
# hyper_params: (10.0, 70.0, 35.0)
# start training...699
# hyper_params: (10.0, 105.0, 1480.0)
# start training...700
# hyper_params: (10.0, 35.0, 1920.0)
# start training...701
# hyper_params: (10.0, 685.0, 830.0)
# start training...702
# hyper_params: (10.0, 300.0, 40.0)
# start training...703
# hyper_params: (10.0, 145.0, 535.0)
# start training...704
# hyper_params: (10.0, 235.0, 1730.0)
# start training...705
# hyper_params: (10.0, 185.0, 670.0)
# start training...706
# hyper_params: (10.0, 590.0, 1295.0)
# start training...707
# hyper_params: (7.0, 85.0, 260.0)
# start training...708
# hyper_params: (10.0, 120.0, 4235.0)
# start training...709
# hyper_params: (10.0, 395.0, 955.0)
# start training...710
# hyper_params: (10.0, 50.0, 490.0)
# start training...711
# hyper_params: (10.0, 65.0, 2135.0)
# start training...712
# hyper_params: (10.0, 95.0, 1510.0)
# start training...713
# hyper_params: (10.0, 135.0, 810.0)
# start training...714
# hyper_params: (10.0, 170.0, 1080.0)
# start training...715
# hyper_params: (10.0, 205.0, 3950.0)
# start training...716
# hyper_params: (10.0, 75.0, 410.0)
# start training...717
# hyper_params: (10.0, 35.0, 185.0)
# start training...718
# hyper_params: (10.0, 245.0, 45.0)
# start training...719
# hyper_params: (10.0, 55.0, 1250.0)
# start training...720
# hyper_params: (10.0, 110.0, 1905.0)
# start training...721
# hyper_params: (10.0, 270.0, 655.0)
# start training...722
# hyper_params: (10.0, 35.0, 1625.0)
# start training...723
# hyper_params: (10.0, 155.0, 2240.0)
# start training...724
# hyper_params: (10.0, 125.0, 845.0)
# start training...725
# hyper_params: (10.0, 90.0, 1095.0)
# start training...726
# hyper_params: (10.0, 785.0, 310.0)
# start training...727
# hyper_params: (10.0, 70.0, 3105.0)
# start training...728
# hyper_params: (10.0, 730.0, 1365.0)
# start training...729
# hyper_params: (7.0, 350.0, 8240.0)
# start training...730
# hyper_params: (10.0, 35.0, 565.0)
# start training...731
# hyper_params: (10.0, 175.0, 1770.0)
# start training...732
# hyper_params: (10.0, 145.0, 465.0)
# start training...733
# hyper_params: (10.0, 215.0, 55.0)
# start training...734
# hyper_params: (10.0, 105.0, 250.0)
# start training...735
# hyper_params: (10.0, 55.0, 890.0)
# start training...736
# hyper_params: (10.0, 125.0, 7105.0)
# start training...737
# hyper_params: (10.0, 830.0, 5250.0)
# start training...738
# hyper_params: (10.0, 315.0, 2515.0)
# start training...739
# hyper_params: (10.0, 85.0, 1990.0)
# start training...740
# hyper_params: (10.0, 185.0, 2790.0)
# start training...741
# hyper_params: (10.0, 35.0, 1170.0)
# start training...742
# hyper_params: (10.0, 70.0, 40.0)
# start training...743
# hyper_params: (10.0, 30.0, 1505.0)
# start training...744
# hyper_params: (10.0, 145.0, 630.0)
# start training...745
# hyper_params: (10.0, 110.0, 920.0)
# start training...746
# hyper_params: (10.0, 475.0, 215.0)
# start training...747
# hyper_params: (10.0, 30.0, 420.0)
# start training...748
# hyper_params: (10.0, 50.0, 370.0)
# start training...749
# hyper_params: (10.0, 160.0, 3460.0)
# start training...750
# hyper_params: (10.0, 80.0, 765.0)
# start training...751
# hyper_params: (10.0, 195.0, 45.0)
# start training...752
# hyper_params: (10.0, 100.0, 1260.0)
# start training...753
# hyper_params: (10.0, 55.0, 1045.0)
# start training...754
# hyper_params: (10.0, 120.0, 430.0)
# start training...755
# hyper_params: (10.0, 425.0, 1465.0)
# start training...756
# hyper_params: (10.0, 245.0, 620.0)
# start training...757
# hyper_params: (10.0, 135.0, 45.0)
# start training...758
# hyper_params: (10.0, 950.0, 1625.0)
# start training...759
# hyper_params: (10.0, 65.0, 260.0)
# start training...760
# hyper_params: (10.0, 95.0, 4830.0)
# start training...761
# hyper_params: (10.0, 170.0, 6265.0)
# start training...762
# hyper_params: (10.0, 220.0, 2115.0)
# start training...763
# hyper_params: (10.0, 45.0, 795.0)
# start training...764
# hyper_params: (10.0, 35.0, 1020.0)
# start training...765
# hyper_params: (10.0, 75.0, 2335.0)
# start training...766
# hyper_params: (10.0, 135.0, 1785.0)
# start training...767
# hyper_params: (10.0, 30.0, 1220.0)
# start training...768
# hyper_params: (10.0, 30.0, 465.0)
# start training...769
# hyper_params: (10.0, 290.0, 35.0)
# start training...770
# hyper_params: (10.0, 105.0, 1395.0)
# start training...771
# hyper_params: (10.0, 90.0, 750.0)
# start training...772
# hyper_params: (10.0, 635.0, 230.0)
# start training...773
# hyper_params: (10.0, 205.0, 1005.0)
# start training...774
# hyper_params: (5.0, 150.0, 1970.0)
# start training...775
# hyper_params: (10.0, 60.0, 35.0)
# start training...776
# hyper_params: (10.0, 120.0, 490.0)
# start training...777
# hyper_params: (10.0, 180.0, 1630.0)
# start training...778
# hyper_params: (10.0, 75.0, 1185.0)
# start training...779
# hyper_params: (10.0, 555.0, 890.0)
# start training...780
# hyper_params: (10.0, 50.0, 35.0)
# start training...781
# hyper_params: (10.0, 90.0, 620.0)
# start training...782
# hyper_params: (10.0, 160.0, 320.0)
# start training...783
# hyper_params: (10.0, 265.0, 1475.0)
# start training...784
# hyper_params: (10.0, 35.0, 615.0)
# start training...785
# hyper_params: (10.0, 50.0, 470.0)
# start training...786
# hyper_params: (10.0, 70.0, 835.0)
# start training...787
# hyper_params: (10.0, 35.0, 680.0)
# start training...788
# hyper_params: (10.0, 55.0, 260.0)
# start training...789
# hyper_params: (10.0, 80.0, 1050.0)
# start training...790
# hyper_params: (7.0, 105.0, 460.0)
# start training...791
# hyper_params: (10.0, 35.0, 225.0)
# start training...792
# hyper_params: (10.0, 60.0, 35.0)
# start training...793
# hyper_params: (10.0, 30.0, 810.0)
# start training...794
# hyper_params: (7.0, 90.0, 605.0)
# start training...795
# hyper_params: (10.0, 50.0, 1230.0)
# start training...796
# hyper_params: (10.0, 75.0, 375.0)
# start training...797
# hyper_params: (10.0, 115.0, 995.0)
# start training...798
# hyper_params: (7.0, 100.0, 730.0)
# start training...799
# hyper_params: (10.0, 50.0, 170.0)
# start training...800
# hyper_params: (7.0, 30.0, 1330.0)
# start training...801
# hyper_params: (10.0, 130.0, 485.0)
# start training...802
# hyper_params: (10.0, 75.0, 945.0)
# start training...803
# hyper_params: (10.0, 35.0, 220.0)
# start training...804
# hyper_params: (7.0, 60.0, 1135.0)
# start training...805
# hyper_params: (10.0, 95.0, 565.0)
# start training...806
# hyper_params: (10.0, 30.0, 850.0)
# start training...807
# hyper_params: (7.0, 115.0, 305.0)
# start training...808
# hyper_params: (10.0, 70.0, 1385.0)
# start training...809
# hyper_params: (10.0, 135.0, 40.0)
# start training...810
# hyper_params: (7.0, 85.0, 725.0)
# start training...811
# hyper_params: (10.0, 55.0, 1130.0)
# start training...812
# hyper_params: (10.0, 35.0, 40.0)
# start training...813
# hyper_params: (7.0, 105.0, 425.0)
# start training...814
# hyper_params: (10.0, 145.0, 35.0)
# start training...815
# hyper_params: (10.0, 50.0, 945.0)
# start training...816
# hyper_params: (10.0, 80.0, 1675.0)
# start training...817
# hyper_params: (7.0, 115.0, 670.0)
# start training...818
# hyper_params: (10.0, 30.0, 1290.0)
# start training...819
# hyper_params: (10.0, 70.0, 575.0)
# start training...820
# hyper_params: (7.0, 30.0, 235.0)
# start training...821
# hyper_params: (10.0, 130.0, 1475.0)
# start training...822
# hyper_params: (5.0, 95.0, 1060.0)
# start training...823
# hyper_params: (10.0, 50.0, 35.0)
# start training...824
# hyper_params: (10.0, 155.0, 425.0)
# start training...825
# hyper_params: (7.0, 60.0, 1795.0)
# start training...826
# hyper_params: (9.0, 120.0, 795.0)
# start training...827
# hyper_params: (10.0, 95.0, 1220.0)
# start training...828
# hyper_params: (10.0, 35.0, 950.0)
# start training...829
# hyper_params: (9.0, 75.0, 330.0)
# start training...830
# hyper_params: (7.0, 140.0, 550.0)
# start training...831
# hyper_params: (10.0, 175.0, 1455.0)
# start training...832
# hyper_params: (10.0, 50.0, 35.0)
# start training...833
# hyper_params: (7.0, 90.0, 790.0)
# start training...834
# hyper_params: (9.0, 115.0, 230.0)
# start training...835
# hyper_params: (10.0, 65.0, 1130.0)
# start training...836
# hyper_params: (8.0, 105.0, 605.0)
# start training...837
# hyper_params: (10.0, 35.0, 1665.0)
# start training...838
# hyper_params: (9.0, 30.0, 900.0)
# start training...839
# hyper_params: (10.0, 150.0, 1330.0)
# start training...840
# hyper_params: (7.0, 80.0, 345.0)
# start training...841
# hyper_params: (8.0, 130.0, 520.0)
# start training...842
# hyper_params: (10.0, 170.0, 1555.0)
# start training...843
# hyper_params: (9.0, 60.0, 1820.0)
# start training...844
# hyper_params: (8.0, 190.0, 180.0)
# start training...845
# hyper_params: (10.0, 50.0, 745.0)
# start training...846
# hyper_params: (7.0, 110.0, 1075.0)
# start training...847
# hyper_params: (9.0, 85.0, 2015.0)
# start training...848
# hyper_params: (10.0, 70.0, 7375.0)
# start training...849
# hyper_params: (10.0, 140.0, 465.0)
# start training...850
# hyper_params: (8.0, 35.0, 35.0)
# start training...851
# hyper_params: (9.0, 100.0, 1310.0)
# start training...852
# hyper_params: (7.0, 660.0, 955.0)
# start training...853
# hyper_params: (10.0, 125.0, 265.0)
# start training...854
# hyper_params: (8.0, 30.0, 8610.0)
# start training...855
# hyper_params: (10.0, 155.0, 770.0)
# start training...856
# hyper_params: (9.0, 65.0, 1175.0)
# start training...857
# hyper_params: (10.0, 50.0, 1565.0)
# start training...858
# hyper_params: (7.0, 85.0, 35.0)
# start training...859
# hyper_params: (8.0, 195.0, 600.0)
# start training...860
# hyper_params: (10.0, 35.0, 320.0)
# start training...861
# hyper_params: (9.0, 105.0, 900.0)
# start training...862
# hyper_params: (10.0, 750.0, 2190.0)
# start training...863
# hyper_params: (8.0, 170.0, 1860.0)
# start training...864
# hyper_params: (7.0, 125.0, 455.0)
# start training...865
# hyper_params: (10.0, 50.0, 1360.0)
# start training...866
# hyper_params: (8.0, 75.0, 715.0)
# start training...867
# hyper_params: (10.0, 90.0, 1090.0)
# start training...868
# hyper_params: (9.0, 65.0, 4640.0)
# start training...869
# hyper_params: (9.0, 150.0, 50.0)
# start training...870
# hyper_params: (7.0, 605.0, 375.0)
# start training...871
# hyper_params: (10.0, 1025.0, 195.0)
# start training...872
# hyper_params: (8.0, 105.0, 35.0)
# start training...873
# hyper_params: (10.0, 50.0, 1615.0)
# start training...874
# hyper_params: (9.0, 35.0, 630.0)
# start training...875
# hyper_params: (9.0, 890.0, 935.0)
# start training...876
# hyper_params: (9.0, 980.0, 1280.0)
# start training...877
# hyper_params: (9.0, 380.0, 2060.0)
# start training...878
# hyper_params: (9.0, 85.0, 655.0)
# start training...879
# hyper_params: (10.0, 225.0, 1125.0)
# start training...880
# hyper_params: (10.0, 135.0, 1490.0)
# start training...881
# hyper_params: (9.0, 165.0, 2380.0)
# start training...882
# hyper_params: (10.0, 30.0, 1790.0)
# start training...883
# hyper_params: (9.0, 200.0, 815.0)
# start training...884
# hyper_params: (10.0, 35.0, 420.0)
# start training...885
# hyper_params: (10.0, 115.0, 1040.0)
# start training...886
# hyper_params: (9.0, 70.0, 1395.0)
# start training...887
# hyper_params: (10.0, 50.0, 645.0)
# start training...888
# hyper_params: (10.0, 95.0, 205.0)
# start training...889
# hyper_params: (10.0, 120.0, 6045.0)
# start training...890
# hyper_params: (9.0, 180.0, 855.0)
# start training...891
# hyper_params: (9.0, 145.0, 1935.0)
# start training...892
# hyper_params: (10.0, 30.0, 2590.0)
# start training...893
# hyper_params: (10.0, 65.0, 1160.0)
# start training...894
# hyper_params: (10.0, 85.0, 1675.0)
# start training...895
# hyper_params: (9.0, 50.0, 370.0)
# start training...896
# hyper_params: (10.0, 500.0, 210.0)
# start training...897
# hyper_params: (9.0, 105.0, 575.0)
# start training...898
# hyper_params: (10.0, 35.0, 1310.0)
# start training...899
# hyper_params: (10.0, 445.0, 760.0)
# start training...900
# hyper_params: (9.0, 135.0, 1490.0)
# start training...901
# hyper_params: (10.0, 80.0, 955.0)
# start training...902
# hyper_params: (10.0, 210.0, 2290.0)
# start training...903
# hyper_params: (9.0, 160.0, 40.0)
# start training...904
# hyper_params: (10.0, 65.0, 430.0)
# start training...905
# hyper_params: (10.0, 30.0, 200.0)
# start training...906
# hyper_params: (9.0, 240.0, 1140.0)
# start training...907
# hyper_params: (10.0, 120.0, 655.0)
# start training...908
# hyper_params: (10.0, 90.0, 7860.0)
# start training...909
# hyper_params: (6.0, 190.0, 1650.0)
# start training...910
# hyper_params: (9.0, 55.0, 4070.0)
# start training...911
# hyper_params: (10.0, 105.0, 1850.0)
# start training...912
# hyper_params: (9.0, 35.0, 855.0)
# start training...913
# hyper_params: (9.0, 160.0, 2805.0)
# start training...914
# hyper_params: (9.0, 135.0, 2160.0)
# start training...915
# hyper_params: (9.0, 75.0, 5710.0)
# start training...916
# hyper_params: (9.0, 120.0, 1305.0)
# start training...917
# hyper_params: (9.0, 30.0, 6890.0)
# start training...918
# hyper_params: (9.0, 55.0, 1935.0)
# start training...919
# hyper_params: (9.0, 540.0, 990.0)
# start training...920
# hyper_params: (9.0, 175.0, 1480.0)
# start training...921
# hyper_params: (9.0, 105.0, 1670.0)
# start training...922
# hyper_params: (9.0, 220.0, 2990.0)
# start training...923
# hyper_params: (9.0, 70.0, 2585.0)
# start training...924
# hyper_params: (9.0, 150.0, 805.0)
# start training...925
# hyper_params: (9.0, 810.0, 1255.0)
# start training...926
# hyper_params: (9.0, 50.0, 975.0)
# start training...927
# hyper_params: (9.0, 915.0, 2015.0)
# start training...928
# hyper_params: (9.0, 95.0, 1485.0)
# start training...929
# hyper_params: (9.0, 35.0, 4375.0)
# start training...930
# hyper_params: (9.0, 125.0, 2320.0)
# start training...931
# hyper_params: (9.0, 80.0, 610.0)
# start training...932
# hyper_params: (9.0, 50.0, 1145.0)
# start training...933
# hyper_params: (9.0, 190.0, 885.0)
# start training...934
# hyper_params: (9.0, 30.0, 1825.0)
# start training...935
# hyper_params: (9.0, 695.0, 45.0)
# start training...936
# hyper_params: (9.0, 570.0, 410.0)
# start training...937
# hyper_params: (9.0, 140.0, 750.0)
# start training...938
# hyper_params: (9.0, 95.0, 1355.0)
# start training...939
# hyper_params: (9.0, 70.0, 240.0)
# start training...940
# hyper_params: (9.0, 170.0, 9200.0)
# start training...941
# hyper_params: (9.0, 115.0, 540.0)
# start training...942
# hyper_params: (9.0, 320.0, 3825.0)
# start training...943
# hyper_params: (9.0, 50.0, 1085.0)
# start training...944
# hyper_params: (9.0, 80.0, 40.0)
# start training...945
# hyper_params: (9.0, 405.0, 2165.0)
# start training...946
# hyper_params: (9.0, 255.0, 1500.0)
# start training...947
# hyper_params: (9.0, 35.0, 1730.0)
# start training...948
# hyper_params: (6.0, 855.0, 5135.0)
# start training...949
# hyper_params: (9.0, 210.0, 720.0)
# start training...950
# hyper_params: (7.0, 150.0, 1240.0)
# start training...951
# hyper_params: (9.0, 105.0, 9440.0)
# start training...952
# hyper_params: (9.0, 65.0, 980.0)
# start training...953
# hyper_params: (7.0, 130.0, 245.0)
# start training...954
# hyper_params: (9.0, 90.0, 600.0)
# start training...955
# hyper_params: (9.0, 30.0, 370.0)
# start training...956
# hyper_params: (5.0, 465.0, 1615.0)
# start training...957
# hyper_params: (7.0, 50.0, 885.0)
# start training...958
# hyper_params: (9.0, 30.0, 2005.0)
# start training...959
# hyper_params: (9.0, 180.0, 50.0)
# start training...960
# hyper_params: (9.0, 230.0, 535.0)
# start training...961
# hyper_params: (7.0, 65.0, 40.0)
# start training...962
# hyper_params: (6.0, 355.0, 1160.0)
# start training...963
# hyper_params: (9.0, 160.0, 2505.0)
# start training...964
# hyper_params: (7.0, 120.0, 1445.0)
# start training...965
# hyper_params: (9.0, 95.0, 765.0)
# start training...966
# hyper_params: (9.0, 75.0, 3550.0)
# start training...967
# hyper_params: (9.0, 135.0, 215.0)
# start training...968
# hyper_params: (7.0, 955.0, 9775.0)
# start training...969
# hyper_params: (9.0, 35.0, 1755.0)
# start training...970
# hyper_params: (9.0, 200.0, 1015.0)
# start training...971
# hyper_params: (7.0, 50.0, 7560.0)
# start training...972
# hyper_params: (10.0, 30.0, 420.0)
# start training...973
# hyper_params: (10.0, 105.0, 3240.0)
# start training...974
# hyper_params: (9.0, 85.0, 1265.0)
# start training...975
# hyper_params: (6.0, 155.0, 790.0)
# start training...976
# hyper_params: (10.0, 60.0, 580.0)
# start training...977
# hyper_params: (10.0, 175.0, 250.0)
# start training...978
# hyper_params: (10.0, 280.0, 505.0)
# start training...979
# hyper_params: (10.0, 240.0, 1355.0)
# start training...980
# hyper_params: (10.0, 130.0, 1025.0)
# start training...981
# hyper_params: (10.0, 215.0, 1585.0)
# start training...982
# hyper_params: (10.0, 195.0, 825.0)
# start training...983
# hyper_params: (10.0, 150.0, 2045.0)
# start training...984
# hyper_params: (10.0, 110.0, 40.0)
# start training...985
# hyper_params: (10.0, 70.0, 2730.0)
# start training...986
# hyper_params: (10.0, 120.0, 45.0)
# start training...987
# hyper_params: (10.0, 85.0, 8985.0)
# start training...988
# hyper_params: (10.0, 60.0, 345.0)
# start training...989
# hyper_params: (10.0, 140.0, 1185.0)
# start training...990
# hyper_params: (10.0, 95.0, 2370.0)
# start training...991
# hyper_params: (10.0, 620.0, 5435.0)
# start training...992
# hyper_params: (10.0, 175.0, 35.0)
# start training...993
# hyper_params: (10.0, 265.0, 620.0)
# start training...994
# hyper_params: (10.0, 55.0, 1860.0)
# start training...995
# hyper_params: (10.0, 160.0, 905.0)
# start training...996
# hyper_params: (10.0, 110.0, 465.0)
# start training...997
# hyper_params: (10.0, 65.0, 1405.0)
# start training...998
# hyper_params: (10.0, 140.0, 215.0)
# start training...999
# {'max_depth': 10.0, 'min_data_in_leaf': 565.0, 'num_leaves': 35.0}

# %%
test_y_pred_agg = np.zeros(shape=test_y.shape)
for test_y_pred in test_y_pred_list:
    test_y_pred_agg += test_y_pred
test_y_pred_agg /= len(test_y_pred_list)

print('Test msre is: ' + str(sqrt(mean_squared_error(test_y_tmp, test_y_pred_agg))))
# Out:
# Test msre is: 0.0

# %%
tpe_trials.results
# Out:
# [{'loss': 1.0489852283746777, 'status': 'ok'},
#  {'loss': 1.0484295488979563, 'status': 'ok'},
#  {'loss': 1.0529061439142497, 'status': 'ok'},
#  {'loss': 1.0256654398984903, 'status': 'ok'},
#  {'loss': 1.0533371222391328, 'status': 'ok'},
#  {'loss': 1.0539926454246016, 'status': 'ok'},
#  {'loss': 1.0467743984110414, 'status': 'ok'},
#  {'loss': 1.052725270175449, 'status': 'ok'},
#  {'loss': 1.046422771902942, 'status': 'ok'},
#  {'loss': 1.0480135168797728, 'status': 'ok'},
#  {'loss': 1.053601648433423, 'status': 'ok'},
#  {'loss': 1.0272364714298896, 'status': 'ok'},
#  {'loss': 1.0380943002252152, 'status': 'ok'},
#  {'loss': 1.0526738807409093, 'status': 'ok'},
#  {'loss': 1.0469845904950983, 'status': 'ok'},
#  {'loss': 1.0548726142570182, 'status': 'ok'},
#  {'loss': 1.0498507141721223, 'status': 'ok'},
#  {'loss': 1.0531865191298027, 'status': 'ok'},
#  {'loss': 1.0277236464899961, 'status': 'ok'},
#  {'loss': 1.051521088763826, 'status': 'ok'},
#  {'loss': 1.0278288494588421, 'status': 'ok'},
#  {'loss': 1.0340897792878345, 'status': 'ok'},
#  {'loss': 1.0360510101128102, 'status': 'ok'},
#  {'loss': 1.0447366855183968, 'status': 'ok'},
#  {'loss': 1.030645985333941, 'status': 'ok'},
#  {'loss': 1.039661862309038, 'status': 'ok'},
#  {'loss': 1.0454934910661766, 'status': 'ok'},
#  {'loss': 1.0265862463537982, 'status': 'ok'},
#  {'loss': 1.0319004814308508, 'status': 'ok'},
#  {'loss': 1.0262293494085313, 'status': 'ok'},
#  {'loss': 1.044563546442896, 'status': 'ok'},
#  {'loss': 1.0291018974595538, 'status': 'ok'},
#  {'loss': 1.0408881006373643, 'status': 'ok'},
#  {'loss': 1.032276846822096, 'status': 'ok'},
#  {'loss': 1.0472800163254121, 'status': 'ok'},
#  {'loss': 1.0373865522221313, 'status': 'ok'},
#  {'loss': 1.0566495673706036, 'status': 'ok'},
#  {'loss': 1.0474204709990773, 'status': 'ok'},
#  {'loss': 1.0492470008201173, 'status': 'ok'},
#  {'loss': 1.049230187937749, 'status': 'ok'},
#  {'loss': 1.0457187480855352, 'status': 'ok'},
#  {'loss': 1.024462381048827, 'status': 'ok'},
#  {'loss': 1.0387982925452945, 'status': 'ok'},
#  {'loss': 1.0309053576527905, 'status': 'ok'},
#  {'loss': 1.0270198824061085, 'status': 'ok'},
#  {'loss': 1.046538059933221, 'status': 'ok'},
#  {'loss': 1.0561673399301552, 'status': 'ok'},
#  {'loss': 1.0351472713132956, 'status': 'ok'},
#  {'loss': 1.0446820077695764, 'status': 'ok'},
#  {'loss': 1.0536704170479785, 'status': 'ok'},
#  {'loss': 1.052017529886915, 'status': 'ok'},
#  {'loss': 1.0277833402226932, 'status': 'ok'},
#  {'loss': 1.0275796892261604, 'status': 'ok'},
#  {'loss': 1.0324962709264682, 'status': 'ok'},
#  {'loss': 1.0458831181814312, 'status': 'ok'},
#  {'loss': 1.05046907840687, 'status': 'ok'},
#  {'loss': 1.0435388456952013, 'status': 'ok'},
#  {'loss': 1.0322290598415191, 'status': 'ok'},
#  {'loss': 1.0385169501365437, 'status': 'ok'},
#  {'loss': 1.0288418737225933, 'status': 'ok'},
#  {'loss': 1.0388397383835295, 'status': 'ok'},
#  {'loss': 1.045876116531368, 'status': 'ok'},
#  {'loss': 1.025870115221238, 'status': 'ok'},
#  {'loss': 1.0478235175958002, 'status': 'ok'},
#  {'loss': 1.048786765298929, 'status': 'ok'},
#  {'loss': 1.0253954201725457, 'status': 'ok'},
#  {'loss': 1.0322633591573382, 'status': 'ok'},
#  {'loss': 1.0283858027549218, 'status': 'ok'},
#  {'loss': 1.0265320217824505, 'status': 'ok'},
#  {'loss': 1.0287074025329241, 'status': 'ok'},
#  {'loss': 1.0432443618221183, 'status': 'ok'},
#  {'loss': 1.0303887743926854, 'status': 'ok'},
#  {'loss': 1.037144696375043, 'status': 'ok'},
#  {'loss': 1.0389756705209658, 'status': 'ok'},
#  {'loss': 1.0345890021384296, 'status': 'ok'},
#  {'loss': 1.0393669021468148, 'status': 'ok'},
#  {'loss': 1.0264137096782902, 'status': 'ok'},
#  {'loss': 1.0371363327211, 'status': 'ok'},
#  {'loss': 1.0266195366255835, 'status': 'ok'},
#  {'loss': 1.0571589777374442, 'status': 'ok'},
#  {'loss': 1.05112464769008, 'status': 'ok'},
#  {'loss': 1.0502481614306507, 'status': 'ok'},
#  {'loss': 1.0357768764682664, 'status': 'ok'},
#  {'loss': 1.0427109523900193, 'status': 'ok'},
#  {'loss': 1.0271639113467252, 'status': 'ok'},
#  {'loss': 1.0507228841328686, 'status': 'ok'},
#  {'loss': 1.0322220249772405, 'status': 'ok'},
#  {'loss': 1.0273153345597201, 'status': 'ok'},
#  {'loss': 1.0303891098610043, 'status': 'ok'},
#  {'loss': 1.0428730808165463, 'status': 'ok'},
#  {'loss': 1.02661487904175, 'status': 'ok'},
#  {'loss': 1.0295863503359333, 'status': 'ok'},
#  {'loss': 1.0508091508338853, 'status': 'ok'},
#  {'loss': 1.0460664807171778, 'status': 'ok'},
#  {'loss': 1.0334503371978982, 'status': 'ok'},
#  {'loss': 1.052361585109641, 'status': 'ok'},
#  {'loss': 1.053113800581653, 'status': 'ok'},
#  {'loss': 1.0389629818513773, 'status': 'ok'},
#  {'loss': 1.0497604774031024, 'status': 'ok'},
#  {'loss': 1.0455712275892275, 'status': 'ok'},
#  {'loss': 1.0272282463031894, 'status': 'ok'},
#  {'loss': 1.0496307947684143, 'status': 'ok'},
#  {'loss': 1.0523879830796339, 'status': 'ok'},
#  {'loss': 1.051527771558693, 'status': 'ok'},
#  {'loss': 1.0467711768779724, 'status': 'ok'},
#  {'loss': 1.0297388085981494, 'status': 'ok'},
#  {'loss': 1.0363549359273014, 'status': 'ok'},
#  {'loss': 1.0307881917926758, 'status': 'ok'},
#  {'loss': 1.0266427007007688, 'status': 'ok'},
#  {'loss': 1.0331861467179657, 'status': 'ok'},
#  {'loss': 1.0525821036103755, 'status': 'ok'},
#  {'loss': 1.0314106040525293, 'status': 'ok'},
#  {'loss': 1.0258348225114584, 'status': 'ok'},
#  {'loss': 1.044699418812123, 'status': 'ok'},
#  {'loss': 1.0350146912041251, 'status': 'ok'},
#  {'loss': 1.0372510492798677, 'status': 'ok'},
#  {'loss': 1.0267870454612273, 'status': 'ok'},
#  {'loss': 1.0428968934165246, 'status': 'ok'},
#  {'loss': 1.039868419505434, 'status': 'ok'},
#  {'loss': 1.0569481639426284, 'status': 'ok'},
#  {'loss': 1.0525995119908187, 'status': 'ok'},
#  {'loss': 1.0488863745044643, 'status': 'ok'},
#  {'loss': 1.0491164117780325, 'status': 'ok'},
#  {'loss': 1.0310754741959978, 'status': 'ok'},
#  {'loss': 1.0528919741779246, 'status': 'ok'},
#  {'loss': 1.0265862463537982, 'status': 'ok'},
#  {'loss': 1.0489694147272266, 'status': 'ok'},
#  {'loss': 1.0252708401888517, 'status': 'ok'},
#  {'loss': 1.0506401058446202, 'status': 'ok'},
#  {'loss': 1.0473375748779858, 'status': 'ok'},
#  {'loss': 1.0509191887221958, 'status': 'ok'},
#  {'loss': 1.0358011966313083, 'status': 'ok'},
#  {'loss': 1.0285857676006551, 'status': 'ok'},
#  {'loss': 1.032276846822096, 'status': 'ok'},
#  {'loss': 1.026014802892366, 'status': 'ok'},
#  {'loss': 1.0507699172532101, 'status': 'ok'},
#  {'loss': 1.050836207517063, 'status': 'ok'},
#  {'loss': 1.04399910440746, 'status': 'ok'},
#  {'loss': 1.028998291356473, 'status': 'ok'},
#  {'loss': 1.0490774224744288, 'status': 'ok'},
#  {'loss': 1.042982692526371, 'status': 'ok'},
#  {'loss': 1.0407418556674837, 'status': 'ok'},
#  {'loss': 1.0356231138355743, 'status': 'ok'},
#  {'loss': 1.0329305263622546, 'status': 'ok'},
#  {'loss': 1.0280710089473815, 'status': 'ok'},
#  {'loss': 1.0242735987909386, 'status': 'ok'},
#  {'loss': 1.0235283345438986, 'status': 'ok'},
#  {'loss': 1.024592711116933, 'status': 'ok'},
#  {'loss': 1.0312551902559386, 'status': 'ok'},
#  {'loss': 1.0263607582879264, 'status': 'ok'},
#  {'loss': 1.0261316162706944, 'status': 'ok'},
#  {'loss': 1.0300061335775044, 'status': 'ok'},
#  {'loss': 1.0365841729773262, 'status': 'ok'},
#  {'loss': 1.0241637716256184, 'status': 'ok'},
#  {'loss': 1.0299684334901935, 'status': 'ok'},
#  {'loss': 1.028497264685621, 'status': 'ok'},
#  {'loss': 1.0365533695454485, 'status': 'ok'},
#  {'loss': 1.0316335072072667, 'status': 'ok'},
#  {'loss': 1.0271669804832881, 'status': 'ok'},
#  {'loss': 1.0382917763079134, 'status': 'ok'},
#  {'loss': 1.0353352133277685, 'status': 'ok'},
#  {'loss': 1.0431712549764842, 'status': 'ok'},
#  {'loss': 1.029649213229754, 'status': 'ok'},
#  {'loss': 1.0262618601881113, 'status': 'ok'},
#  {'loss': 1.0271693563892792, 'status': 'ok'},
#  {'loss': 1.0499339277751654, 'status': 'ok'},
#  {'loss': 1.0345182053408866, 'status': 'ok'},
#  {'loss': 1.0307971024622105, 'status': 'ok'},
#  {'loss': 1.0394413409020933, 'status': 'ok'},
#  {'loss': 1.0237832884280968, 'status': 'ok'},
#  {'loss': 1.0323044313481735, 'status': 'ok'},
#  {'loss': 1.0264899409826989, 'status': 'ok'},
#  {'loss': 1.0380618481569015, 'status': 'ok'},
#  {'loss': 1.0352288018914055, 'status': 'ok'},
#  {'loss': 1.0347185607777383, 'status': 'ok'},
#  {'loss': 1.0547912252679976, 'status': 'ok'},
#  {'loss': 1.028458727728926, 'status': 'ok'},
#  {'loss': 1.0500735906451957, 'status': 'ok'},
#  {'loss': 1.0493472478637589, 'status': 'ok'},
#  {'loss': 1.0263623423461454, 'status': 'ok'},
#  {'loss': 1.0491095979357299, 'status': 'ok'},
#  {'loss': 1.0287932755786615, 'status': 'ok'},
#  {'loss': 1.0428290711416697, 'status': 'ok'},
#  {'loss': 1.0489181198700046, 'status': 'ok'},
#  {'loss': 1.0328080691201968, 'status': 'ok'},
#  {'loss': 1.0435234743236173, 'status': 'ok'},
#  {'loss': 1.0270055697842353, 'status': 'ok'},
#  {'loss': 1.0551187866925058, 'status': 'ok'},
#  {'loss': 1.0267547479031909, 'status': 'ok'},
#  {'loss': 1.0352564565955928, 'status': 'ok'},
#  {'loss': 1.0488011382634317, 'status': 'ok'},
#  {'loss': 1.0539016118884525, 'status': 'ok'},
#  {'loss': 1.0525835912711319, 'status': 'ok'},
#  {'loss': 1.0467927959080947, 'status': 'ok'},
#  {'loss': 1.032741708594066, 'status': 'ok'},
#  {'loss': 1.0285616959955934, 'status': 'ok'},
#  {'loss': 1.0336476970449593, 'status': 'ok'},
#  {'loss': 1.0424491664116546, 'status': 'ok'},
#  {'loss': 1.0278080803676897, 'status': 'ok'},
#  {'loss': 1.0377043747306616, 'status': 'ok'},
#  {'loss': 1.0242175001125997, 'status': 'ok'},
#  {'loss': 1.0325500127762828, 'status': 'ok'},
#  {'loss': 1.0333217501377805, 'status': 'ok'},
#  {'loss': 1.033473174143537, 'status': 'ok'},
#  {'loss': 1.0266983812755393, 'status': 'ok'},
#  {'loss': 1.0266752206951475, 'status': 'ok'},
#  {'loss': 1.0504008638178701, 'status': 'ok'},
#  {'loss': 1.0334611271966538, 'status': 'ok'},
#  {'loss': 1.0497617523546314, 'status': 'ok'},
#  {'loss': 1.0256563655858506, 'status': 'ok'},
#  {'loss': 1.0449143710778608, 'status': 'ok'},
#  {'loss': 1.027736407164679, 'status': 'ok'},
#  {'loss': 1.0504494955402635, 'status': 'ok'},
#  {'loss': 1.0384769589750078, 'status': 'ok'},
#  {'loss': 1.0296742484452956, 'status': 'ok'},
#  {'loss': 1.0340694904764116, 'status': 'ok'},
#  {'loss': 1.0351857303937502, 'status': 'ok'},
#  {'loss': 1.0415429164029903, 'status': 'ok'},
#  {'loss': 1.0288777508066387, 'status': 'ok'},
#  {'loss': 1.0280765708226411, 'status': 'ok'},
#  {'loss': 1.0429294744883386, 'status': 'ok'},
#  {'loss': 1.0301482700269886, 'status': 'ok'},
#  {'loss': 1.0264519504824605, 'status': 'ok'},
#  {'loss': 1.03682626690191, 'status': 'ok'},
#  {'loss': 1.0462602459081844, 'status': 'ok'},
#  {'loss': 1.025152304122823, 'status': 'ok'},
#  {'loss': 1.033333934456707, 'status': 'ok'},
#  {'loss': 1.0563292730783664, 'status': 'ok'},
#  {'loss': 1.0324530316789229, 'status': 'ok'},
#  {'loss': 1.0254350869351716, 'status': 'ok'},
#  {'loss': 1.030063558121499, 'status': 'ok'},
#  {'loss': 1.0530439384748511, 'status': 'ok'},
#  {'loss': 1.0420411135826768, 'status': 'ok'},
#  {'loss': 1.0242106343453545, 'status': 'ok'},
#  {'loss': 1.0336120371864277, 'status': 'ok'},
#  {'loss': 1.052862879769182, 'status': 'ok'},
#  {'loss': 1.0276807535034356, 'status': 'ok'},
#  {'loss': 1.0282349967670807, 'status': 'ok'},
#  {'loss': 1.0303834773043088, 'status': 'ok'},
#  {'loss': 1.026555782620186, 'status': 'ok'},
#  {'loss': 1.0517420400093813, 'status': 'ok'},
#  {'loss': 1.0326245860664327, 'status': 'ok'},
#  {'loss': 1.0271171990464252, 'status': 'ok'},
#  {'loss': 1.031997121980053, 'status': 'ok'},
#  {'loss': 1.0266895295161207, 'status': 'ok'},
#  {'loss': 1.050373863902399, 'status': 'ok'},
#  {'loss': 1.037000118961602, 'status': 'ok'},
#  {'loss': 1.0344535411394968, 'status': 'ok'},
#  {'loss': 1.0280111278453266, 'status': 'ok'},
#  {'loss': 1.0444060190771247, 'status': 'ok'},
#  {'loss': 1.0520265190432687, 'status': 'ok'},
#  {'loss': 1.050478426617322, 'status': 'ok'},
#  {'loss': 1.0263776406873524, 'status': 'ok'},
#  {'loss': 1.0361099943943362, 'status': 'ok'},
#  {'loss': 1.026246067677188, 'status': 'ok'},
#  {'loss': 1.0279545708735323, 'status': 'ok'},
#  {'loss': 1.0481571300279842, 'status': 'ok'},
#  {'loss': 1.0322508130573385, 'status': 'ok'},
#  {'loss': 1.0250674548687195, 'status': 'ok'},
#  {'loss': 1.0258133476234432, 'status': 'ok'},
#  {'loss': 1.028016443128043, 'status': 'ok'},
#  {'loss': 1.0305210677319485, 'status': 'ok'},
#  {'loss': 1.0288670975125618, 'status': 'ok'},
#  {'loss': 1.0271650928912963, 'status': 'ok'},
#  {'loss': 1.0246045744278034, 'status': 'ok'},
#  {'loss': 1.0325502714251777, 'status': 'ok'},
#  {'loss': 1.0245157021245719, 'status': 'ok'},
#  {'loss': 1.0319812496469691, 'status': 'ok'},
#  {'loss': 1.0352303349309153, 'status': 'ok'},
#  {'loss': 1.028882141910921, 'status': 'ok'},
#  {'loss': 1.0214851973332335, 'status': 'ok'},
#  {'loss': 1.0358975483246353, 'status': 'ok'},
#  {'loss': 1.0285477516498842, 'status': 'ok'},
#  {'loss': 1.0298566019695512, 'status': 'ok'},
#  {'loss': 1.0296511345635322, 'status': 'ok'},
#  {'loss': 1.0272768501216594, 'status': 'ok'},
#  {'loss': 1.0373821432170556, 'status': 'ok'},
#  {'loss': 1.0251079505182659, 'status': 'ok'},
#  {'loss': 1.028163032128767, 'status': 'ok'},
#  {'loss': 1.0414436235320397, 'status': 'ok'},
#  {'loss': 1.03193342313879, 'status': 'ok'},
#  {'loss': 1.0271394226373618, 'status': 'ok'},
#  {'loss': 1.031262774864326, 'status': 'ok'},
#  {'loss': 1.0245809669258883, 'status': 'ok'},
#  {'loss': 1.0330370884460323, 'status': 'ok'},
#  {'loss': 1.0414617862542916, 'status': 'ok'},
#  {'loss': 1.0265711254799337, 'status': 'ok'},
#  {'loss': 1.032624809310766, 'status': 'ok'},
#  {'loss': 1.028341314650197, 'status': 'ok'},
#  {'loss': 1.0346284532481413, 'status': 'ok'},
#  {'loss': 1.0330601504930066, 'status': 'ok'},
#  {'loss': 1.0538806981763025, 'status': 'ok'},
#  {'loss': 1.0424746311674982, 'status': 'ok'},
#  {'loss': 1.0301704579945383, 'status': 'ok'},
#  {'loss': 1.0255036063339518, 'status': 'ok'},
#  {'loss': 1.0333995268380183, 'status': 'ok'},
#  {'loss': 1.0359161253189602, 'status': 'ok'},
#  {'loss': 1.0259444326319958, 'status': 'ok'},
#  {'loss': 1.0376739311322345, 'status': 'ok'},
#  {'loss': 1.052111346495819, 'status': 'ok'},
#  {'loss': 1.0465189890156144, 'status': 'ok'},
#  {'loss': 1.0281450006680923, 'status': 'ok'},
#  {'loss': 1.0478459544204441, 'status': 'ok'},
#  {'loss': 1.0526766353792214, 'status': 'ok'},
#  {'loss': 1.026065838190108, 'status': 'ok'},
#  {'loss': 1.0472203948284493, 'status': 'ok'},
#  {'loss': 1.0326016744216744, 'status': 'ok'},
#  {'loss': 1.0243442144347432, 'status': 'ok'},
#  {'loss': 1.0362645444682368, 'status': 'ok'},
#  {'loss': 1.0565313407363717, 'status': 'ok'},
#  {'loss': 1.0446968482965078, 'status': 'ok'},
#  {'loss': 1.0448521375194688, 'status': 'ok'},
#  {'loss': 1.0276773165384612, 'status': 'ok'},
#  {'loss': 1.0324028682125626, 'status': 'ok'},
#  {'loss': 1.0301383932955632, 'status': 'ok'},
#  {'loss': 1.0270583282671215, 'status': 'ok'},
#  {'loss': 1.0402577935381598, 'status': 'ok'},
#  {'loss': 1.030517219920991, 'status': 'ok'},
#  {'loss': 1.030427566388909, 'status': 'ok'},
#  {'loss': 1.0294622885097322, 'status': 'ok'},
#  {'loss': 1.040100018035878, 'status': 'ok'},
#  {'loss': 1.0317152611747848, 'status': 'ok'},
#  {'loss': 1.040904879750077, 'status': 'ok'},
#  {'loss': 1.02508677646942, 'status': 'ok'},
#  {'loss': 1.0355800940987183, 'status': 'ok'},
#  {'loss': 1.0272945137843328, 'status': 'ok'},
#  {'loss': 1.027794358111128, 'status': 'ok'},
#  {'loss': 1.0286746949237147, 'status': 'ok'},
#  {'loss': 1.0367035195518068, 'status': 'ok'},
#  {'loss': 1.0318494244258136, 'status': 'ok'},
#  {'loss': 1.0328379846665563, 'status': 'ok'},
#  {'loss': 1.030785990900603, 'status': 'ok'},
#  {'loss': 1.0286815323673928, 'status': 'ok'},
#  {'loss': 1.0261293835779768, 'status': 'ok'},
#  {'loss': 1.0242121816020189, 'status': 'ok'},
#  {'loss': 1.0273958431403059, 'status': 'ok'},
#  {'loss': 1.0485450864460384, 'status': 'ok'},
#  {'loss': 1.0359419090066604, 'status': 'ok'},
#  {'loss': 1.0425242386431863, 'status': 'ok'},
#  {'loss': 1.0520636865257254, 'status': 'ok'},
#  {'loss': 1.0327590527589512, 'status': 'ok'},
#  {'loss': 1.0375558365556348, 'status': 'ok'},
#  {'loss': 1.0330774288362894, 'status': 'ok'},
#  {'loss': 1.0304483363484995, 'status': 'ok'},
#  {'loss': 1.027189418528418, 'status': 'ok'},
#  {'loss': 1.0281456446884465, 'status': 'ok'},
#  {'loss': 1.0326532334162106, 'status': 'ok'},
#  {'loss': 1.0448041249965658, 'status': 'ok'},
#  {'loss': 1.0539369571743944, 'status': 'ok'},
#  {'loss': 1.0484412405070889, 'status': 'ok'},
#  {'loss': 1.022895907514504, 'status': 'ok'},
#  {'loss': 1.0366310365695746, 'status': 'ok'},
#  {'loss': 1.0408168353634941, 'status': 'ok'},
#  {'loss': 1.0292599640173339, 'status': 'ok'},
#  {'loss': 1.0471036350129759, 'status': 'ok'},
#  {'loss': 1.0266594638631457, 'status': 'ok'},
#  {'loss': 1.03588465489704, 'status': 'ok'},
#  {'loss': 1.0499897754702392, 'status': 'ok'},
#  {'loss': 1.0448910446119006, 'status': 'ok'},
#  {'loss': 1.0509474981913192, 'status': 'ok'},
#  {'loss': 1.045656287701288, 'status': 'ok'},
#  {'loss': 1.0256677381097683, 'status': 'ok'},
#  {'loss': 1.0449543505484817, 'status': 'ok'},
#  {'loss': 1.0362665629130272, 'status': 'ok'},
#  {'loss': 1.0318915936830746, 'status': 'ok'},
#  {'loss': 1.034360960522397, 'status': 'ok'},
#  {'loss': 1.0245396976747312, 'status': 'ok'},
#  {'loss': 1.02999342753996, 'status': 'ok'},
#  {'loss': 1.0290938618379866, 'status': 'ok'},
#  {'loss': 1.0366812647740917, 'status': 'ok'},
#  {'loss': 1.051005466314071, 'status': 'ok'},
#  {'loss': 1.0409785935790377, 'status': 'ok'},
#  {'loss': 1.028402779035351, 'status': 'ok'},
#  {'loss': 1.0317942996872658, 'status': 'ok'},
#  {'loss': 1.0263087379356481, 'status': 'ok'},
#  {'loss': 1.0278124525029981, 'status': 'ok'},
#  {'loss': 1.0516324353643032, 'status': 'ok'},
#  {'loss': 1.0229007503617686, 'status': 'ok'},
#  {'loss': 1.0372362203516166, 'status': 'ok'},
#  {'loss': 1.0355493355066305, 'status': 'ok'},
#  {'loss': 1.040486084468921, 'status': 'ok'},
#  {'loss': 1.0333697081605877, 'status': 'ok'},
#  {'loss': 1.0366303770932384, 'status': 'ok'},
#  {'loss': 1.0281546313920462, 'status': 'ok'},
#  {'loss': 1.0280027191809784, 'status': 'ok'},
#  {'loss': 1.0404783051573285, 'status': 'ok'},
#  {'loss': 1.0258763282783447, 'status': 'ok'},
#  {'loss': 1.035702298776817, 'status': 'ok'},
#  {'loss': 1.027257487068187, 'status': 'ok'},
#  {'loss': 1.029637318508745, 'status': 'ok'},
#  {'loss': 1.0368378140104855, 'status': 'ok'},
#  {'loss': 1.0376777928867935, 'status': 'ok'},
#  {'loss': 1.052378039578674, 'status': 'ok'},
#  {'loss': 1.0332168296460773, 'status': 'ok'},
#  {'loss': 1.023516058069366, 'status': 'ok'},
#  {'loss': 1.048352471202746, 'status': 'ok'},
#  {'loss': 1.0423448646896907, 'status': 'ok'},
#  {'loss': 1.0270904402832275, 'status': 'ok'},
#  {'loss': 1.0333088470771505, 'status': 'ok'},
#  {'loss': 1.0279957946076665, 'status': 'ok'},
#  {'loss': 1.0251556781966593, 'status': 'ok'},
#  {'loss': 1.021998976794404, 'status': 'ok'},
#  {'loss': 1.0271655961651793, 'status': 'ok'},
#  {'loss': 1.0232972570315604, 'status': 'ok'},
#  {'loss': 1.0263810223924008, 'status': 'ok'},
#  {'loss': 1.0260353414089354, 'status': 'ok'},
#  {'loss': 1.0251778822946334, 'status': 'ok'},
#  {'loss': 1.030018843258279, 'status': 'ok'},
#  {'loss': 1.027158238758731, 'status': 'ok'},
#  {'loss': 1.030604043396038, 'status': 'ok'},
#  {'loss': 1.0227587972307581, 'status': 'ok'},
#  {'loss': 1.0262248469292625, 'status': 'ok'},
#  {'loss': 1.02457633917, 'status': 'ok'},
#  {'loss': 1.0295412400943864, 'status': 'ok'},
#  {'loss': 1.028671052804728, 'status': 'ok'},
#  {'loss': 1.0313519850997197, 'status': 'ok'},
#  {'loss': 1.022583904176535, 'status': 'ok'},
#  {'loss': 1.02714797559457, 'status': 'ok'},
#  {'loss': 1.0415182131658967, 'status': 'ok'},
#  {'loss': 1.030235993234576, 'status': 'ok'},
#  {'loss': 1.0361382695037917, 'status': 'ok'},
#  {'loss': 1.0298056395788042, 'status': 'ok'},
#  {'loss': 1.0290910126078132, 'status': 'ok'},
#  {'loss': 1.025844487144699, 'status': 'ok'},
#  {'loss': 1.0305230097331917, 'status': 'ok'},
#  {'loss': 1.0394187588884884, 'status': 'ok'},
#  {'loss': 1.0243002480100896, 'status': 'ok'},
#  {'loss': 1.034365452824401, 'status': 'ok'},
#  {'loss': 1.028087352888435, 'status': 'ok'},
#  {'loss': 1.030604937386027, 'status': 'ok'},
#  {'loss': 1.0353424616277882, 'status': 'ok'},
#  {'loss': 1.0340768727170506, 'status': 'ok'},
#  {'loss': 1.0306548177017132, 'status': 'ok'},
#  {'loss': 1.023880866241987, 'status': 'ok'},
#  {'loss': 1.0317233470653886, 'status': 'ok'},
#  {'loss': 1.0506199230742355, 'status': 'ok'},
#  {'loss': 1.0339124777596749, 'status': 'ok'},
#  {'loss': 1.0282424122653246, 'status': 'ok'},
#  {'loss': 1.040195841043809, 'status': 'ok'},
#  {'loss': 1.0352586779070958, 'status': 'ok'},
#  {'loss': 1.0238911871787009, 'status': 'ok'},
#  {'loss': 1.0238469590237773, 'status': 'ok'},
#  {'loss': 1.0285263199143058, 'status': 'ok'},
#  {'loss': 1.030881027553664, 'status': 'ok'},
#  {'loss': 1.0229512139702568, 'status': 'ok'},
#  {'loss': 1.0331618333910886, 'status': 'ok'},
#  {'loss': 1.0374954826848939, 'status': 'ok'},
#  {'loss': 1.0257594277559914, 'status': 'ok'},
#  {'loss': 1.0286895316966223, 'status': 'ok'},
#  {'loss': 1.026309631462392, 'status': 'ok'},
#  {'loss': 1.0262480063271746, 'status': 'ok'},
#  {'loss': 1.0351730806020436, 'status': 'ok'},
#  {'loss': 1.052736599758345, 'status': 'ok'},
#  {'loss': 1.0333026187608616, 'status': 'ok'},
#  {'loss': 1.0234390340139579, 'status': 'ok'},
#  {'loss': 1.0296643359005773, 'status': 'ok'},
#  {'loss': 1.0346818299439906, 'status': 'ok'},
#  {'loss': 1.0294191346084862, 'status': 'ok'},
#  {'loss': 1.0444305585520477, 'status': 'ok'},
#  {'loss': 1.042904960676297, 'status': 'ok'},
#  {'loss': 1.0261765288447933, 'status': 'ok'},
#  {'loss': 1.0279088755435348, 'status': 'ok'},
#  {'loss': 1.0375007650939758, 'status': 'ok'},
#  {'loss': 1.0312188219444844, 'status': 'ok'},
#  {'loss': 1.031958923317991, 'status': 'ok'},
#  {'loss': 1.0335673451192624, 'status': 'ok'},
#  {'loss': 1.0217557650782887, 'status': 'ok'},
#  {'loss': 1.0267755343849412, 'status': 'ok'},
#  {'loss': 1.0363770712229738, 'status': 'ok'},
#  {'loss': 1.0526148949239327, 'status': 'ok'},
#  {'loss': 1.0493480744856265, 'status': 'ok'},
#  {'loss': 1.0487765916479848, 'status': 'ok'},
#  {'loss': 1.027976057920416, 'status': 'ok'},
#  {'loss': 1.0300243454710176, 'status': 'ok'},
#  {'loss': 1.0288198497477419, 'status': 'ok'},
#  {'loss': 1.0419927120791632, 'status': 'ok'},
#  {'loss': 1.0354723816080686, 'status': 'ok'},
#  {'loss': 1.0396371009735077, 'status': 'ok'},
#  {'loss': 1.029890436626856, 'status': 'ok'},
#  {'loss': 1.0257506425932124, 'status': 'ok'},
#  {'loss': 1.0466579476709046, 'status': 'ok'},
#  {'loss': 1.04108684567177, 'status': 'ok'},
#  {'loss': 1.0303716727594907, 'status': 'ok'},
#  {'loss': 1.0461384427390323, 'status': 'ok'},
#  {'loss': 1.028459881000375, 'status': 'ok'},
#  {'loss': 1.023167743420119, 'status': 'ok'},
#  {'loss': 1.0310406479518788, 'status': 'ok'},
#  {'loss': 1.0276554774888067, 'status': 'ok'},
#  {'loss': 1.027410240797332, 'status': 'ok'},
#  {'loss': 1.0361549148411044, 'status': 'ok'},
#  {'loss': 1.0238491776222733, 'status': 'ok'},
#  {'loss': 1.0411262176467633, 'status': 'ok'},
#  {'loss': 1.052039063487169, 'status': 'ok'},
#  {'loss': 1.0334263887338881, 'status': 'ok'},
#  {'loss': 1.030941549231049, 'status': 'ok'},
#  {'loss': 1.0325100567597805, 'status': 'ok'},
#  {'loss': 1.0255499023762769, 'status': 'ok'},
#  {'loss': 1.0389420181210167, 'status': 'ok'},
#  {'loss': 1.027043182010704, 'status': 'ok'},
#  {'loss': 1.030832574193507, 'status': 'ok'},
#  {'loss': 1.0472895875742485, 'status': 'ok'},
#  {'loss': 1.0292956102186752, 'status': 'ok'},
#  {'loss': 1.0378689962998622, 'status': 'ok'},
#  {'loss': 1.024653919302116, 'status': 'ok'},
#  {'loss': 1.0424842995670962, 'status': 'ok'},
#  {'loss': 1.0489588759526025, 'status': 'ok'},
#  {'loss': 1.039312889720388, 'status': 'ok'},
#  {'loss': 1.0321407007118442, 'status': 'ok'},
#  {'loss': 1.0471378602647512, 'status': 'ok'},
#  {'loss': 1.0287634951433333, 'status': 'ok'},
#  {'loss': 1.0364948263346332, 'status': 'ok'},
#  {'loss': 1.0269062242244165, 'status': 'ok'},
#  {'loss': 1.0249814942229172, 'status': 'ok'},
#  {'loss': 1.0466271432090775, 'status': 'ok'},
#  {'loss': 1.0280092245804147, 'status': 'ok'},
#  {'loss': 1.050837954097628, 'status': 'ok'},
#  {'loss': 1.0310623679723858, 'status': 'ok'},
#  {'loss': 1.0325237481288216, 'status': 'ok'},
#  {'loss': 1.0485792685680781, 'status': 'ok'},
#  {'loss': 1.0360869302641227, 'status': 'ok'},
#  {'loss': 1.0258692790060489, 'status': 'ok'},
#  {'loss': 1.036769287034902, 'status': 'ok'},
#  {'loss': 1.0292374497059342, 'status': 'ok'},
#  {'loss': 1.029756334887416, 'status': 'ok'},
#  {'loss': 1.0246014381109059, 'status': 'ok'},
#  {'loss': 1.0279132031123461, 'status': 'ok'},
#  {'loss': 1.0347315502474828, 'status': 'ok'},
#  {'loss': 1.0308328960287272, 'status': 'ok'},
#  {'loss': 1.0299834778017072, 'status': 'ok'},
#  {'loss': 1.0283504130669678, 'status': 'ok'},
#  {'loss': 1.0456805583841857, 'status': 'ok'},
#  {'loss': 1.0321730199715236, 'status': 'ok'},
#  {'loss': 1.0425071219716993, 'status': 'ok'},
#  {'loss': 1.025781980802895, 'status': 'ok'},
#  {'loss': 1.02840503748925, 'status': 'ok'},
#  {'loss': 1.0309063076038223, 'status': 'ok'},
#  {'loss': 1.0374897772319958, 'status': 'ok'},
#  {'loss': 1.0291468942638182, 'status': 'ok'},
#  {'loss': 1.0430430790884924, 'status': 'ok'},
#  {'loss': 1.0280614453837194, 'status': 'ok'},
#  {'loss': 1.0258665687259818, 'status': 'ok'},
#  {'loss': 1.0358873141012714, 'status': 'ok'},
#  {'loss': 1.0519018216525629, 'status': 'ok'},
#  {'loss': 1.048912083708784, 'status': 'ok'},
#  {'loss': 1.029476755496743, 'status': 'ok'},
#  {'loss': 1.032065705021609, 'status': 'ok'},
#  {'loss': 1.0275099952591062, 'status': 'ok'},
#  {'loss': 1.041464449084259, 'status': 'ok'},
#  {'loss': 1.0291232701163409, 'status': 'ok'},
#  {'loss': 1.0256646151372353, 'status': 'ok'},
#  {'loss': 1.0290482705215074, 'status': 'ok'},
#  {'loss': 1.0280326838411538, 'status': 'ok'},
#  {'loss': 1.0487756065647298, 'status': 'ok'},
#  {'loss': 1.047245050458031, 'status': 'ok'},
#  {'loss': 1.050714021055301, 'status': 'ok'},
#  {'loss': 1.0351047712208512, 'status': 'ok'},
#  {'loss': 1.0278080803676897, 'status': 'ok'},
#  {'loss': 1.029075792968901, 'status': 'ok'},
#  {'loss': 1.0490397612368219, 'status': 'ok'},
#  {'loss': 1.0292916613147745, 'status': 'ok'},
#  {'loss': 1.0329913929104653, 'status': 'ok'},
#  {'loss': 1.0378813148394315, 'status': 'ok'},
#  {'loss': 1.0317017033313884, 'status': 'ok'},
#  {'loss': 1.0242735987909386, 'status': 'ok'},
#  {'loss': 1.0297723905085234, 'status': 'ok'},
#  {'loss': 1.0344337085996647, 'status': 'ok'},
#  {'loss': 1.0311952252547203, 'status': 'ok'},
#  {'loss': 1.0296138271988513, 'status': 'ok'},
#  {'loss': 1.042431748307078, 'status': 'ok'},
#  {'loss': 1.0274690817295802, 'status': 'ok'},
#  {'loss': 1.0313969295011836, 'status': 'ok'},
#  {'loss': 1.0304338714324899, 'status': 'ok'},
#  {'loss': 1.0382698763451998, 'status': 'ok'},
#  {'loss': 1.0526250909392483, 'status': 'ok'},
#  {'loss': 1.0277346269810668, 'status': 'ok'},
#  {'loss': 1.037326225366499, 'status': 'ok'},
#  {'loss': 1.0330147764790174, 'status': 'ok'},
#  {'loss': 1.0237564235032048, 'status': 'ok'},
#  {'loss': 1.022350362225991, 'status': 'ok'},
#  {'loss': 1.0224524876180994, 'status': 'ok'},
#  {'loss': 1.0236555525354494, 'status': 'ok'},
#  {'loss': 1.0273600430470693, 'status': 'ok'},
#  {'loss': 1.0288385589391156, 'status': 'ok'},
#  {'loss': 1.022559672536802, 'status': 'ok'},
#  {'loss': 1.0280110505059186, 'status': 'ok'},
#  {'loss': 1.033715627188464, 'status': 'ok'},
#  {'loss': 1.0243379938993462, 'status': 'ok'},
#  {'loss': 1.0302442796567743, 'status': 'ok'},
#  {'loss': 1.0330915093548874, 'status': 'ok'},
#  {'loss': 1.0254676649309515, 'status': 'ok'},
#  {'loss': 1.0239426861110204, 'status': 'ok'},
#  {'loss': 1.0281300216381382, 'status': 'ok'},
#  {'loss': 1.031749312218686, 'status': 'ok'},
#  {'loss': 1.029325567627019, 'status': 'ok'},
#  {'loss': 1.027281116410201, 'status': 'ok'},
#  {'loss': 1.0273917778805837, 'status': 'ok'},
#  {'loss': 1.0269282407635634, 'status': 'ok'},
#  {'loss': 1.0276866731174494, 'status': 'ok'},
#  {'loss': 1.0313359822966497, 'status': 'ok'},
#  {'loss': 1.029189756713555, 'status': 'ok'},
#  {'loss': 1.0306611571823685, 'status': 'ok'},
#  {'loss': 1.0224165582784057, 'status': 'ok'},
#  {'loss': 1.029489630499857, 'status': 'ok'},
#  {'loss': 1.026478459233857, 'status': 'ok'},
#  {'loss': 1.023520747083226, 'status': 'ok'},
#  {'loss': 1.0347048700259895, 'status': 'ok'},
#  {'loss': 1.0235797217451241, 'status': 'ok'},
#  {'loss': 1.0318317516234183, 'status': 'ok'},
#  {'loss': 1.0245579775676237, 'status': 'ok'},
#  {'loss': 1.0322981747792197, 'status': 'ok'},
#  {'loss': 1.0283433374743782, 'status': 'ok'},
#  {'loss': 1.0270322927775024, 'status': 'ok'},
#  {'loss': 1.030907290880375, 'status': 'ok'},
#  {'loss': 1.05477089886876, 'status': 'ok'},
#  {'loss': 1.0261239341911912, 'status': 'ok'},
#  {'loss': 1.0312910016852836, 'status': 'ok'},
#  {'loss': 1.0361344752198374, 'status': 'ok'},
#  {'loss': 1.0328154704872188, 'status': 'ok'},
#  {'loss': 1.0366058791955939, 'status': 'ok'},
#  {'loss': 1.0251714984091629, 'status': 'ok'},
#  {'loss': 1.0223554339184275, 'status': 'ok'},
#  {'loss': 1.0338361731505468, 'status': 'ok'},
#  {'loss': 1.0228626436244372, 'status': 'ok'},
#  {'loss': 1.0306445540468605, 'status': 'ok'},
#  {'loss': 1.034374690589729, 'status': 'ok'},
#  {'loss': 1.025689252270797, 'status': 'ok'},
#  {'loss': 1.0276205027641132, 'status': 'ok'},
#  {'loss': 1.0255832043608832, 'status': 'ok'},
#  {'loss': 1.0385132176277874, 'status': 'ok'},
#  {'loss': 1.028885749905963, 'status': 'ok'},
#  {'loss': 1.0358742876788904, 'status': 'ok'},
#  {'loss': 1.027656923121345, 'status': 'ok'},
#  {'loss': 1.0295931380650523, 'status': 'ok'},
#  {'loss': 1.051047729726083, 'status': 'ok'},
#  {'loss': 1.0345460395103887, 'status': 'ok'},
#  {'loss': 1.027806107530994, 'status': 'ok'},
#  {'loss': 1.029227563887758, 'status': 'ok'},
#  {'loss': 1.036827957629566, 'status': 'ok'},
#  {'loss': 1.028304873285475, 'status': 'ok'},
#  {'loss': 1.0297639060549137, 'status': 'ok'},
#  {'loss': 1.025085765191814, 'status': 'ok'},
#  {'loss': 1.0258152439838122, 'status': 'ok'},
#  {'loss': 1.0363888927576297, 'status': 'ok'},
#  {'loss': 1.032111820643234, 'status': 'ok'},
#  {'loss': 1.031324549717713, 'status': 'ok'},
#  {'loss': 1.029469597130316, 'status': 'ok'},
#  {'loss': 1.0232987183234892, 'status': 'ok'},
#  {'loss': 1.0338407959044909, 'status': 'ok'},
#  {'loss': 1.0332405371391902, 'status': 'ok'},
#  {'loss': 1.0261765206648426, 'status': 'ok'},
#  {'loss': 1.0488192097375861, 'status': 'ok'},
#  {'loss': 1.0242132734923446, 'status': 'ok'},
#  {'loss': 1.025758305244638, 'status': 'ok'},
#  {'loss': 1.0289254516425415, 'status': 'ok'},
#  {'loss': 1.0345917459253435, 'status': 'ok'},
#  {'loss': 1.0275998853219648, 'status': 'ok'},
#  {'loss': 1.0333088470771505, 'status': 'ok'},
#  {'loss': 1.0307622465428503, 'status': 'ok'},
#  {'loss': 1.0493956550213577, 'status': 'ok'},
#  {'loss': 1.0532779370488998, 'status': 'ok'},
#  {'loss': 1.038398830199691, 'status': 'ok'},
#  {'loss': 1.0298061629501034, 'status': 'ok'},
#  {'loss': 1.0280139261697472, 'status': 'ok'},
#  {'loss': 1.0276327960243745, 'status': 'ok'},
#  {'loss': 1.025132992752534, 'status': 'ok'},
#  {'loss': 1.0412440051306975, 'status': 'ok'},
#  {'loss': 1.0480352348061182, 'status': 'ok'},
#  {'loss': 1.0341576444072205, 'status': 'ok'},
#  {'loss': 1.0372784806050142, 'status': 'ok'},
#  {'loss': 1.0228758216919076, 'status': 'ok'},
#  {'loss': 1.0368355116880446, 'status': 'ok'},
#  {'loss': 1.0271837140814988, 'status': 'ok'},
#  {'loss': 1.031171988595823, 'status': 'ok'},
#  {'loss': 1.0331760851181955, 'status': 'ok'},
#  {'loss': 1.0269788357554435, 'status': 'ok'},
#  {'loss': 1.0420094374664615, 'status': 'ok'},
#  {'loss': 1.0250579654773908, 'status': 'ok'},
#  {'loss': 1.0477906466688012, 'status': 'ok'},
#  {'loss': 1.038923599430091, 'status': 'ok'},
#  {'loss': 1.0322953328168036, 'status': 'ok'},
#  {'loss': 1.0217600892585799, 'status': 'ok'},
#  {'loss': 1.04865485315018, 'status': 'ok'},
#  {'loss': 1.0299655514620831, 'status': 'ok'},
#  {'loss': 1.0443831105643568, 'status': 'ok'},
#  {'loss': 1.025592247421274, 'status': 'ok'},
#  {'loss': 1.0446968526786533, 'status': 'ok'},
#  {'loss': 1.0312555678994142, 'status': 'ok'},
#  {'loss': 1.0294866132228224, 'status': 'ok'},
#  {'loss': 1.0431562575664348, 'status': 'ok'},
#  {'loss': 1.0380161875376248, 'status': 'ok'},
#  {'loss': 1.0248118267378805, 'status': 'ok'},
#  {'loss': 1.0267272349351486, 'status': 'ok'},
#  {'loss': 1.0218546320628268, 'status': 'ok'},
#  {'loss': 1.0253070197442733, 'status': 'ok'},
#  {'loss': 1.029451207950254, 'status': 'ok'},
#  {'loss': 1.0271081882824398, 'status': 'ok'},
#  {'loss': 1.0395083753275627, 'status': 'ok'},
#  {'loss': 1.028351564574538, 'status': 'ok'},
#  {'loss': 1.0274657054943332, 'status': 'ok'},
#  {'loss': 1.0312121135267642, 'status': 'ok'},
#  {'loss': 1.0330412502645092, 'status': 'ok'},
#  {'loss': 1.0349270349529303, 'status': 'ok'},
#  {'loss': 1.0305996533584785, 'status': 'ok'},
#  {'loss': 1.0477629371704036, 'status': 'ok'},
#  {'loss': 1.0301128342731127, 'status': 'ok'},
#  {'loss': 1.0342614941370294, 'status': 'ok'},
#  {'loss': 1.0280171194813306, 'status': 'ok'},
#  {'loss': 1.0287378572453187, 'status': 'ok'},
#  {'loss': 1.028036028878224, 'status': 'ok'},
#  {'loss': 1.0470625809230711, 'status': 'ok'},
#  {'loss': 1.033768644405254, 'status': 'ok'},
#  {'loss': 1.0249708524749044, 'status': 'ok'},
#  {'loss': 1.035585649305036, 'status': 'ok'},
#  {'loss': 1.0307008337679449, 'status': 'ok'},
#  {'loss': 1.0284804984989406, 'status': 'ok'},
#  {'loss': 1.0300454490052537, 'status': 'ok'},
#  {'loss': 1.045487544928058, 'status': 'ok'},
#  {'loss': 1.0233667125471713, 'status': 'ok'},
#  {'loss': 1.024257320167971, 'status': 'ok'},
#  {'loss': 1.0517652781598499, 'status': 'ok'},
#  {'loss': 1.0290844257197622, 'status': 'ok'},
#  {'loss': 1.0355625093495966, 'status': 'ok'},
#  {'loss': 1.029934464212165, 'status': 'ok'},
#  {'loss': 1.0302689146152133, 'status': 'ok'},
#  {'loss': 1.0378296818495116, 'status': 'ok'},
#  {'loss': 1.0277747939226103, 'status': 'ok'},
#  {'loss': 1.0285034137539522, 'status': 'ok'},
#  {'loss': 1.0321468900253148, 'status': 'ok'},
#  {'loss': 1.0425372584693664, 'status': 'ok'},
#  {'loss': 1.0287771344553616, 'status': 'ok'},
#  {'loss': 1.0538814024213385, 'status': 'ok'},
#  {'loss': 1.020119204248413, 'status': 'ok'},
#  {'loss': 1.0361054033191035, 'status': 'ok'},
#  {'loss': 1.0300515915333797, 'status': 'ok'},
#  {'loss': 1.0484628076874225, 'status': 'ok'},
#  {'loss': 1.0286653763748967, 'status': 'ok'},
#  {'loss': 1.0259976383846021, 'status': 'ok'},
#  {'loss': 1.0483837179112618, 'status': 'ok'},
#  {'loss': 1.048786765298929, 'status': 'ok'},
#  {'loss': 1.0403767906526733, 'status': 'ok'},
#  {'loss': 1.0344001563683258, 'status': 'ok'},
#  {'loss': 1.0444211970088713, 'status': 'ok'},
#  {'loss': 1.0283291215708035, 'status': 'ok'},
#  {'loss': 1.0322997359532986, 'status': 'ok'},
#  {'loss': 1.0273389081799578, 'status': 'ok'},
#  {'loss': 1.0286052545755915, 'status': 'ok'},
#  {'loss': 1.028443359113905, 'status': 'ok'},
#  {'loss': 1.035070097826756, 'status': 'ok'},
#  {'loss': 1.0223069124726791, 'status': 'ok'},
#  {'loss': 1.0227873092041397, 'status': 'ok'},
#  {'loss': 1.0448504778548107, 'status': 'ok'},
#  {'loss': 1.0265771889050914, 'status': 'ok'},
#  {'loss': 1.049703599598831, 'status': 'ok'},
#  {'loss': 1.0300475369493323, 'status': 'ok'},
#  {'loss': 1.0267016002474716, 'status': 'ok'},
#  {'loss': 1.0302262554485564, 'status': 'ok'},
#  {'loss': 1.0323422529203488, 'status': 'ok'},
#  {'loss': 1.0292020211951807, 'status': 'ok'},
#  {'loss': 1.0409965476444956, 'status': 'ok'},
#  {'loss': 1.0317429222061079, 'status': 'ok'},
#  {'loss': 1.026468873516192, 'status': 'ok'},
#  {'loss': 1.0468538324491672, 'status': 'ok'},
#  {'loss': 1.0497386556573016, 'status': 'ok'},
#  {'loss': 1.0355092552149823, 'status': 'ok'},
#  {'loss': 1.0234839289466213, 'status': 'ok'},
#  {'loss': 1.0256260989946746, 'status': 'ok'},
#  {'loss': 1.037320667605268, 'status': 'ok'},
#  {'loss': 1.0345917888552425, 'status': 'ok'},
#  {'loss': 1.028455965852964, 'status': 'ok'},
#  {'loss': 1.0225447633566496, 'status': 'ok'},
#  {'loss': 1.0455789668097886, 'status': 'ok'},
#  {'loss': 1.030823930039693, 'status': 'ok'},
#  {'loss': 1.0257173671046733, 'status': 'ok'},
#  {'loss': 1.0305907382299093, 'status': 'ok'},
#  {'loss': 1.0271411517787186, 'status': 'ok'},
#  {'loss': 1.0394681926000007, 'status': 'ok'},
#  {'loss': 1.0360117619732865, 'status': 'ok'},
#  {'loss': 1.0276696627857955, 'status': 'ok'},
#  {'loss': 1.0314173378300793, 'status': 'ok'},
#  {'loss': 1.0263921471902493, 'status': 'ok'},
#  {'loss': 1.029618862132962, 'status': 'ok'},
#  {'loss': 1.0251568059779228, 'status': 'ok'},
#  {'loss': 1.0261024942424313, 'status': 'ok'},
#  {'loss': 1.0305934266627783, 'status': 'ok'},
#  {'loss': 1.030951354699891, 'status': 'ok'},
#  {'loss': 1.0234456620992627, 'status': 'ok'},
#  {'loss': 1.0242958602199623, 'status': 'ok'},
#  {'loss': 1.0283180762253832, 'status': 'ok'},
#  {'loss': 1.0228273838786377, 'status': 'ok'},
#  {'loss': 1.028606226383106, 'status': 'ok'},
#  {'loss': 1.0270050228243897, 'status': 'ok'},
#  {'loss': 1.028016443128043, 'status': 'ok'},
#  {'loss': 1.022771517039784, 'status': 'ok'},
#  {'loss': 1.0360117619732865, 'status': 'ok'},
#  {'loss': 1.024085717707368, 'status': 'ok'},
#  {'loss': 1.0259428665918175, 'status': 'ok'},
#  {'loss': 1.0299682201024118, 'status': 'ok'},
#  {'loss': 1.024199874443629, 'status': 'ok'},
#  {'loss': 1.027831912826919, 'status': 'ok'},
#  {'loss': 1.0256920531654021, 'status': 'ok'},
#  {'loss': 1.0295179169692559, 'status': 'ok'},
#  {'loss': 1.0286904848475957, 'status': 'ok'},
#  {'loss': 1.0274599618609934, 'status': 'ok'},
#  {'loss': 1.0271725746639542, 'status': 'ok'},
#  {'loss': 1.0230334051157408, 'status': 'ok'},
#  {'loss': 1.0299805338344359, 'status': 'ok'},
#  {'loss': 1.0228619973052784, 'status': 'ok'},
#  {'loss': 1.0239455426700554, 'status': 'ok'},
#  {'loss': 1.0281452485197917, 'status': 'ok'},
#  {'loss': 1.0297792111705346, 'status': 'ok'},
#  {'loss': 1.0445144389938774, 'status': 'ok'},
#  {'loss': 1.0260992919887595, 'status': 'ok'},
#  {'loss': 1.028860573388178, 'status': 'ok'},
#  {'loss': 1.0237130182343166, 'status': 'ok'},
#  {'loss': 1.0261037041880314, 'status': 'ok'},
#  {'loss': 1.0461713307579, 'status': 'ok'},
#  {'loss': 1.0264675881020933, 'status': 'ok'},
#  {'loss': 1.0327415908964053, 'status': 'ok'},
#  {'loss': 1.0251491218131914, 'status': 'ok'},
#  {'loss': 1.0286390789070174, 'status': 'ok'},
#  {'loss': 1.0252006244379324, 'status': 'ok'},
#  {'loss': 1.0244037316431387, 'status': 'ok'},
#  {'loss': 1.0319770944566529, 'status': 'ok'},
#  {'loss': 1.0295306573443552, 'status': 'ok'},
#  {'loss': 1.0251568059779228, 'status': 'ok'},
#  {'loss': 1.0284067335965372, 'status': 'ok'},
#  {'loss': 1.0335818925689062, 'status': 'ok'},
#  {'loss': 1.0268364581439138, 'status': 'ok'},
#  {'loss': 1.0285794585134522, 'status': 'ok'},
#  {'loss': 1.0237694491870974, 'status': 'ok'},
#  {'loss': 1.025304663132212, 'status': 'ok'},
#  {'loss': 1.0265015824741475, 'status': 'ok'},
#  {'loss': 1.031119337178308, 'status': 'ok'},
#  {'loss': 1.0251568059779228, 'status': 'ok'},
#  {'loss': 1.028088300076463, 'status': 'ok'},
#  {'loss': 1.0278088318747087, 'status': 'ok'},
#  {'loss': 1.0296341256922237, 'status': 'ok'},
#  {'loss': 1.0251428948087498, 'status': 'ok'},
#  {'loss': 1.0312555678994142, 'status': 'ok'},
#  {'loss': 1.0251907210473599, 'status': 'ok'},
#  {'loss': 1.029097335621167, 'status': 'ok'},
#  {'loss': 1.0254726053876222, 'status': 'ok'},
#  {'loss': 1.0256181600083003, 'status': 'ok'},
#  {'loss': 1.0325718506577821, 'status': 'ok'},
#  {'loss': 1.0348693645208509, 'status': 'ok'},
#  {'loss': 1.0329927266337042, 'status': 'ok'},
#  {'loss': 1.0234665561053582, 'status': 'ok'},
#  {'loss': 1.0286495543117875, 'status': 'ok'},
#  {'loss': 1.0368783601096279, 'status': 'ok'},
#  {'loss': 1.0527568273783214, 'status': 'ok'},
#  {'loss': 1.0282429155198909, 'status': 'ok'},
#  {'loss': 1.0279957946076665, 'status': 'ok'},
#  {'loss': 1.0321192295997879, 'status': 'ok'},
#  {'loss': 1.0294053076330756, 'status': 'ok'},
#  {'loss': 1.0302728550219122, 'status': 'ok'},
#  {'loss': 1.050643087153157, 'status': 'ok'},
#  {'loss': 1.030262567391313, 'status': 'ok'},
#  {'loss': 1.0280998447137728, 'status': 'ok'},
#  {'loss': 1.031783440294098, 'status': 'ok'},
#  {'loss': 1.0293553237750284, 'status': 'ok'},
#  {'loss': 1.0265770478554992, 'status': 'ok'},
#  {'loss': 1.025810817067217, 'status': 'ok'},
#  {'loss': 1.0289861992862146, 'status': 'ok'},
#  {'loss': 1.0376468346072154, 'status': 'ok'},
#  {'loss': 1.036927780817928, 'status': 'ok'},
#  {'loss': 1.0279521313123854, 'status': 'ok'},
#  {'loss': 1.0279218321123305, 'status': 'ok'},
#  {'loss': 1.025482478193582, 'status': 'ok'},
#  {'loss': 1.0275748203727184, 'status': 'ok'},
#  {'loss': 1.049105367005959, 'status': 'ok'},
#  {'loss': 1.041504524567027, 'status': 'ok'},
#  {'loss': 1.0269699949714932, 'status': 'ok'},
#  {'loss': 1.0352529875391636, 'status': 'ok'},
#  {'loss': 1.0327846080585623, 'status': 'ok'},
#  {'loss': 1.0327081786297545, 'status': 'ok'},
#  {'loss': 1.0222736096748952, 'status': 'ok'},
#  {'loss': 1.0298157028236063, 'status': 'ok'},
#  {'loss': 1.0290462093627453, 'status': 'ok'},
#  {'loss': 1.0355850293529556, 'status': 'ok'},
#  {'loss': 1.0270814163443267, 'status': 'ok'},
#  {'loss': 1.0307706470249873, 'status': 'ok'},
#  {'loss': 1.031646763137772, 'status': 'ok'},
#  {'loss': 1.0372023060353093, 'status': 'ok'},
#  {'loss': 1.0344155724208017, 'status': 'ok'},
#  {'loss': 1.0266871858149849, 'status': 'ok'},
#  {'loss': 1.0241961507948782, 'status': 'ok'},
#  {'loss': 1.0288370396385598, 'status': 'ok'},
#  {'loss': 1.0320892660701306, 'status': 'ok'},
#  {'loss': 1.0231753084369812, 'status': 'ok'},
#  {'loss': 1.0291812523569233, 'status': 'ok'},
#  {'loss': 1.049529418736203, 'status': 'ok'},
#  {'loss': 1.0288501060432755, 'status': 'ok'},
#  {'loss': 1.0373189434614285, 'status': 'ok'},
#  {'loss': 1.0391534806125862, 'status': 'ok'},
#  {'loss': 1.02797374495589, 'status': 'ok'},
#  {'loss': 1.0314185381247216, 'status': 'ok'},
#  {'loss': 1.0246193355279072, 'status': 'ok'},
#  {'loss': 1.0312944804719009, 'status': 'ok'},
#  {'loss': 1.0273496912325129, 'status': 'ok'},
#  {'loss': 1.0283948669681429, 'status': 'ok'},
#  {'loss': 1.0304796808940146, 'status': 'ok'},
#  {'loss': 1.0324490185988904, 'status': 'ok'},
#  {'loss': 1.0275805058485696, 'status': 'ok'},
#  {'loss': 1.0375816950945893, 'status': 'ok'},
#  {'loss': 1.0369907216501901, 'status': 'ok'},
#  {'loss': 1.0224468053060143, 'status': 'ok'},
#  {'loss': 1.024443713872733, 'status': 'ok'},
#  {'loss': 1.0290102268654011, 'status': 'ok'},
#  {'loss': 1.0286183030831357, 'status': 'ok'},
#  {'loss': 1.049532555840337, 'status': 'ok'},
#  {'loss': 1.0305585344742947, 'status': 'ok'},
#  {'loss': 1.0467841298883005, 'status': 'ok'},
#  {'loss': 1.0362561231800607, 'status': 'ok'},
#  {'loss': 1.021516798632548, 'status': 'ok'},
#  {'loss': 1.0416577797717301, 'status': 'ok'},
#  {'loss': 1.036073520420474, 'status': 'ok'},
#  {'loss': 1.0476191886965858, 'status': 'ok'},
#  {'loss': 1.029469597130316, 'status': 'ok'},
#  {'loss': 1.046598727464676, 'status': 'ok'},
#  {'loss': 1.0348354051478024, 'status': 'ok'},
#  {'loss': 1.0287357557525116, 'status': 'ok'},
#  {'loss': 1.032567904910863, 'status': 'ok'},
#  {'loss': 1.0325500041061317, 'status': 'ok'},
#  {'loss': 1.0425697434590377, 'status': 'ok'},
#  {'loss': 1.0394614512052804, 'status': 'ok'},
#  {'loss': 1.0273028671701914, 'status': 'ok'},
#  {'loss': 1.029227563887758, 'status': 'ok'},
#  {'loss': 1.0250777558550044, 'status': 'ok'},
#  {'loss': 1.0377333877695005, 'status': 'ok'},
#  {'loss': 1.032391727771664, 'status': 'ok'},
#  {'loss': 1.0454845821852317, 'status': 'ok'},
#  {'loss': 1.0369865869597432, 'status': 'ok'},
#  {'loss': 1.024447647540088, 'status': 'ok'},
#  {'loss': 1.029066347404578, 'status': 'ok'},
#  {'loss': 1.0281553521086237, 'status': 'ok'},
#  {'loss': 1.0335563308590716, 'status': 'ok'},
#  {'loss': 1.042904960676297, 'status': 'ok'},
#  {'loss': 1.0279499808836228, 'status': 'ok'},
#  {'loss': 1.0272313220506037, 'status': 'ok'},
#  {'loss': 1.0311333259418531, 'status': 'ok'},
#  {'loss': 1.030879928675816, 'status': 'ok'},
#  {'loss': 1.0519500779706719, 'status': 'ok'},
#  {'loss': 1.025820680016131, 'status': 'ok'},
#  {'loss': 1.0456803764198424, 'status': 'ok'},
#  {'loss': 1.028916799233151, 'status': 'ok'},
#  {'loss': 1.0337965886462916, 'status': 'ok'},
#  {'loss': 1.037374159054625, 'status': 'ok'},
#  {'loss': 1.0322469466013777, 'status': 'ok'},
#  {'loss': 1.0315948962028658, 'status': 'ok'},
#  {'loss': 1.0508504298571566, 'status': 'ok'},
#  {'loss': 1.0264822438790837, 'status': 'ok'},
#  {'loss': 1.0300267534824132, 'status': 'ok'},
#  {'loss': 1.0505183199385146, 'status': 'ok'},
#  {'loss': 1.025058550694224, 'status': 'ok'},
#  {'loss': 1.0282768760023342, 'status': 'ok'},
#  {'loss': 1.0254543544137005, 'status': 'ok'},
#  {'loss': 1.023619747007519, 'status': 'ok'},
#  {'loss': 1.0326245860664327, 'status': 'ok'},
#  {'loss': 1.026975662126895, 'status': 'ok'},
#  {'loss': 1.0338763715654546, 'status': 'ok'},
#  {'loss': 1.0464540832612095, 'status': 'ok'},
#  {'loss': 1.0262040524780143, 'status': 'ok'},
#  {'loss': 1.028753900112907, 'status': 'ok'},
#  {'loss': 1.0272119688285357, 'status': 'ok'},
#  {'loss': 1.0401268960850951, 'status': 'ok'},
#  {'loss': 1.033333934456707, 'status': 'ok'},
#  {'loss': 1.0274178073594553, 'status': 'ok'},
#  {'loss': 1.0435408343875512, 'status': 'ok'},
#  {'loss': 1.0302069936650216, 'status': 'ok'},
#  {'loss': 1.0524199619557693, 'status': 'ok'},
#  {'loss': 1.0323040279638334, 'status': 'ok'},
#  {'loss': 1.0285182732239257, 'status': 'ok'},
#  {'loss': 1.051804074702653, 'status': 'ok'},
#  {'loss': 1.0223069124726791, 'status': 'ok'},
#  {'loss': 1.0417763573083445, 'status': 'ok'},
#  {'loss': 1.0298838932384133, 'status': 'ok'},
#  {'loss': 1.0272558016963813, 'status': 'ok'},
#  {'loss': 1.0220512015776648, 'status': 'ok'},
#  {'loss': 1.027848708249982, 'status': 'ok'},
#  {'loss': 1.0270784125162171, 'status': 'ok'},
#  {'loss': 1.0298414786503927, 'status': 'ok'},
#  {'loss': 1.02873981601585, 'status': 'ok'},
#  {'loss': 1.0317468455923702, 'status': 'ok'},
#  {'loss': 1.0286432145382574, 'status': 'ok'},
#  {'loss': 1.0368352764301996, 'status': 'ok'},
#  {'loss': 1.03958590337328, 'status': 'ok'},
#  {'loss': 1.0417507288416652, 'status': 'ok'},
#  {'loss': 1.0380271621132442, 'status': 'ok'},
#  {'loss': 1.0511268218634948, 'status': 'ok'},
#  {'loss': 1.025378250722817, 'status': 'ok'},
#  {'loss': 1.0271857112176983, 'status': 'ok'},
#  {'loss': 1.03737481913181, 'status': 'ok'},
#  {'loss': 1.047688554430682, 'status': 'ok'},
#  {'loss': 1.0440230551268594, 'status': 'ok'},
#  {'loss': 1.0293737973460975, 'status': 'ok'},
#  {'loss': 1.0339917840928663, 'status': 'ok'},
#  {'loss': 1.028781605578999, 'status': 'ok'},
#  {'loss': 1.0264705395206435, 'status': 'ok'},
#  {'loss': 1.0285935116270755, 'status': 'ok'},
#  {'loss': 1.0335717356021135, 'status': 'ok'}]

# %%
# lgb_params = {
#                'feature_fraction': 0.75,
#                'metric': 'rmse',
#                'nthread':1, 
#                'min_data_in_leaf': 2**7, 
#                'bagging_fraction': 0.75, 
#                'learning_rate': 0.03, 
#                'objective': 'mse', 
#                'bagging_seed': 2**7, 
#                'num_leaves': 2**6,
#                'bagging_freq':1,
#                'verbose':0 
#               }
# model = lgb.train(lgb_params, lgb.Dataset(train_x, label=train_y), 100)

# pred_y = model.predict(train_x)
# print('Train R-squared for LightGBM is %f' % r2_score(train_y, pred_y))
    
# pred_y = model.predict(test_x)
# if test_y is not None:
#     print('Test R-squared for LightGBM is %f' % r2_score(test_y, pred_y))

# %%
# sqrt(mean_squared_error(test_y, pred_y))

# %%
# model = LinearRegression().fit(train_x, train_y)

# pred_y = model.predict(train_x)
# print('Train R-squared for LinearRegression is %f' % r2_score(train_y, pred_y))
    
# pred_y = model.predict(test_x)
# if test_y is not None:
#     print('Test R-squared for LinearRegression is %f' % r2_score(test_y, pred_y))

# %%
# sqrt(mean_squared_error(test_y, pred_y))
