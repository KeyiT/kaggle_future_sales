# %%
import pandas as pd
import numpy as np
import os
import data
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline 
from tqdm import tqdm_notebook as tn
import gc

import sklearn
from sklearn.model_selection import KFold
from sklearn.preprocessing import RobustScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error
from math import sqrt

import category_encoders as ce
from hyperopt import tpe, fmin, hp, Trials

import lightgbm as lgb

from itertools import product
# Out:
# /Users/keyitang/miniconda3/envs/kaggleFutureSales/lib/python3.6/site-packages/lightgbm/__init__.py:46: UserWarning: Starting from version 2.2.1, the library file in distribution wheels for macOS is built by the Apple Clang (Xcode_8.3.1) compiler.
# This means that in case of installing LightGBM from PyPI via the ``pip install lightgbm`` command, you don't need to install the gcc compiler anymore.
# Instead of that, you need to install the OpenMP library, which is required for running LightGBM on the system with the Apple Clang compiler.
# You can install the OpenMP library by the following command: ``brew install libomp``.
#   "You can install the OpenMP library by the following command: ``brew install libomp``.", UserWarning)

# %%
def downcast_dtypes(df):
    '''
        Changes column types in the dataframe: 
                
                `float64` type to `float32`
                `int64`   type to `int32`
    '''
    
    # Select columns to downcast
    float_cols = [c for c in df if df[c].dtype == "float64"]
    int_cols =   [c for c in df if df[c].dtype == "int64"]
    
    # Downcast
    df[float_cols] = df[float_cols].astype(np.float32)
    df[int_cols]   = df[int_cols].astype(np.int32)
    
    return df

# %% [markdown]
# ## Read Data

# %%
DATA_FOLDER = os.path.join(data.DATA_ROOT, "readonly")
TMP_FOLDER = os.path.join(data.DATA_ROOT, "tmp")
#DATA_FOLDER = "../input"
#TMP_FOLDER = os.path.join(data.DATA_ROOT, "tmp")

VALIDATION_FOLDER = os.path.join(TMP_FOLDER, "validation")
SUBMISSION_FOLDER = os.path.join(TMP_FOLDER, "submission")

# %%
FOLDER = VALIDATION_FOLDER
#FOLDER = SUBMISSION_FOLDER

train_data_path = os.path.join(FOLDER, "train.csv")
test_data_path = os.path.join(FOLDER, "test.csv")

train_data = pd.read_csv(train_data_path).drop(columns=['month', 'date_block_num'])
test_data = pd.read_csv(test_data_path).drop(columns=['month', 'date_block_num'])

train_data = downcast_dtypes(train_data)
test_data = downcast_dtypes(test_data)

print("train data shape: " + str(train_data.shape))
train_data.dtypes
# Out:
# train data shape: (6186922, 88)
# item_category_id                         int32
# shop_id                                  int32
# item_id                                  int32
# target                                 float32
# shop_id_count_month_lag_1              float32
# shop_id_sale_month_lag_1               float32
# item_id_count_month_lag_1              float32
# item_id_sale_month_lag_1               float32
# item_price_mean_month_lag_1            float32
# item_price_std_month_lag_1             float32
# item_shop_cnt_sum_month_lag_1          float32
# item_shop_cnt_std_month_lag_1          float32
# item_shop_sale_sum_month_lag_1         float32
# item_shop_sale_std_month_lag_1         float32
# item_category_id_count_month_lag_1     float32
# item_category_id_sale_month_lag_1      float32
# shop_id_count_month_lag_2              float32
# shop_id_sale_month_lag_2               float32
# item_id_count_month_lag_2              float32
# item_id_sale_month_lag_2               float32
# item_price_mean_month_lag_2            float32
# item_price_std_month_lag_2             float32
# item_shop_cnt_sum_month_lag_2          float32
# item_shop_cnt_std_month_lag_2          float32
# item_shop_sale_sum_month_lag_2         float32
# item_shop_sale_std_month_lag_2         float32
# item_category_id_count_month_lag_2     float32
# item_category_id_sale_month_lag_2      float32
# shop_id_count_month_lag_3              float32
# shop_id_sale_month_lag_3               float32
#                                         ...
# item_shop_cnt_sum_month_lag_5          float32
# item_shop_cnt_std_month_lag_5          float32
# item_shop_sale_sum_month_lag_5         float32
# item_shop_sale_std_month_lag_5         float32
# item_category_id_count_month_lag_5     float32
# item_category_id_sale_month_lag_5      float32
# shop_id_count_month_lag_6              float32
# shop_id_sale_month_lag_6               float32
# item_id_count_month_lag_6              float32
# item_id_sale_month_lag_6               float32
# item_price_mean_month_lag_6            float32
# item_price_std_month_lag_6             float32
# item_shop_cnt_sum_month_lag_6          float32
# item_shop_cnt_std_month_lag_6          float32
# item_shop_sale_sum_month_lag_6         float32
# item_shop_sale_std_month_lag_6         float32
# item_category_id_count_month_lag_6     float32
# item_category_id_sale_month_lag_6      float32
# shop_id_count_month_lag_12             float32
# shop_id_sale_month_lag_12              float32
# item_id_count_month_lag_12             float32
# item_id_sale_month_lag_12              float32
# item_price_mean_month_lag_12           float32
# item_price_std_month_lag_12            float32
# item_shop_cnt_sum_month_lag_12         float32
# item_shop_cnt_std_month_lag_12         float32
# item_shop_sale_sum_month_lag_12        float32
# item_shop_sale_std_month_lag_12        float32
# item_category_id_count_month_lag_12    float32
# item_category_id_sale_month_lag_12     float32
# Length: 88, dtype: object

# %% [markdown]
# ## Make X and y

# %%
train_y = train_data['target']
train_x = train_data.drop(['target'], axis='columns')
feature_names = train_x.columns.tolist()

if 'target' in test_data.columns.tolist():
    test_x = test_data.drop(['target'], axis='columns')
    test_y = test_data['target']
else:
    test_x = test_data

# %% [markdown]
# ## Clipping

# %%
train_y.loc[train_y > 40] = 40
if test_y is not None:
    test_y.loc[test_y > 40] = 40
# Out:
# /Users/keyitang/miniconda3/envs/kaggleFutureSales/lib/python3.6/site-packages/pandas/core/indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %% [markdown]
# ## Categorical Feature Encoding

# %%
categorical_columns = [
    'shop_id', 'item_id', 'item_category_id'
]

# %%
# Leave-One-Out Encoding
categorical_encoder = ce.LeaveOneOutEncoder(cols=categorical_columns, impute_missing=False, drop_invariant=True)
categorical_encoder.fit(train_x, train_y)

train_x = categorical_encoder.transform(train_x)
test_x = categorical_encoder.transform(test_x)

train_x = downcast_dtypes(train_x)
test_x = downcast_dtypes(test_x)

train_x.dtypes
# Out:
# item_category_id                       float32
# shop_id                                float32
# item_id                                float32
# shop_id_count_month_lag_1              float32
# shop_id_sale_month_lag_1               float32
# item_id_count_month_lag_1              float32
# item_id_sale_month_lag_1               float32
# item_price_mean_month_lag_1            float32
# item_price_std_month_lag_1             float32
# item_shop_cnt_sum_month_lag_1          float32
# item_shop_cnt_std_month_lag_1          float32
# item_shop_sale_sum_month_lag_1         float32
# item_shop_sale_std_month_lag_1         float32
# item_category_id_count_month_lag_1     float32
# item_category_id_sale_month_lag_1      float32
# shop_id_count_month_lag_2              float32
# shop_id_sale_month_lag_2               float32
# item_id_count_month_lag_2              float32
# item_id_sale_month_lag_2               float32
# item_price_mean_month_lag_2            float32
# item_price_std_month_lag_2             float32
# item_shop_cnt_sum_month_lag_2          float32
# item_shop_cnt_std_month_lag_2          float32
# item_shop_sale_sum_month_lag_2         float32
# item_shop_sale_std_month_lag_2         float32
# item_category_id_count_month_lag_2     float32
# item_category_id_sale_month_lag_2      float32
# shop_id_count_month_lag_3              float32
# shop_id_sale_month_lag_3               float32
# item_id_count_month_lag_3              float32
#                                         ...
# item_shop_cnt_sum_month_lag_5          float32
# item_shop_cnt_std_month_lag_5          float32
# item_shop_sale_sum_month_lag_5         float32
# item_shop_sale_std_month_lag_5         float32
# item_category_id_count_month_lag_5     float32
# item_category_id_sale_month_lag_5      float32
# shop_id_count_month_lag_6              float32
# shop_id_sale_month_lag_6               float32
# item_id_count_month_lag_6              float32
# item_id_sale_month_lag_6               float32
# item_price_mean_month_lag_6            float32
# item_price_std_month_lag_6             float32
# item_shop_cnt_sum_month_lag_6          float32
# item_shop_cnt_std_month_lag_6          float32
# item_shop_sale_sum_month_lag_6         float32
# item_shop_sale_std_month_lag_6         float32
# item_category_id_count_month_lag_6     float32
# item_category_id_sale_month_lag_6      float32
# shop_id_count_month_lag_12             float32
# shop_id_sale_month_lag_12              float32
# item_id_count_month_lag_12             float32
# item_id_sale_month_lag_12              float32
# item_price_mean_month_lag_12           float32
# item_price_std_month_lag_12            float32
# item_shop_cnt_sum_month_lag_12         float32
# item_shop_cnt_std_month_lag_12         float32
# item_shop_sale_sum_month_lag_12        float32
# item_shop_sale_std_month_lag_12        float32
# item_category_id_count_month_lag_12    float32
# item_category_id_sale_month_lag_12     float32
# Length: 87, dtype: object

# %% [markdown]
# ## Imputation

# %%
train_x.fillna(0, inplace=True)
test_x.fillna(0, inplace=True)

train_y.fillna(0, inplace=True)
test_y.fillna(0, inplace=True)

# %% [markdown]
# ## Normalization

# %%
normalizer = RobustScaler()
normalizer.fit(train_x)

train_x = normalizer.transform(train_x)
test_x = normalizer.transform(test_x)

# train_y = train_y / 20
# if test_y is not None:
#     test_y = test_y / 20.0

# %% [markdown]
# ## Model Training

# %%
lgb_params = {
               'feature_fraction': 0.75,
               'metric': 'rmse',
               'nthread':3, 
               'min_data_in_leaf': 58470, 
               'bagging_fraction': 0.75, 
               'learning_rate': 0.03, 
               'objective': 'mse', 
               'bagging_seed': 2**7, 
               'num_leaves': 2**9,
               'bagging_freq':1,
               'max_depth': 10,
               'verbose':0 
              }

lgb_dataset = lgb.Dataset(train_x, label=train_y)

print("start training...")
model = lgb.train(lgb_params, lgb_dataset, 100)

pred_train_y = model.predict(train_x)
#print('Train R-squared for LightGBM is %f' % r2_score(train_y, pred_y))
    
pred_test_y = model.predict(test_x)
# Out:
# start training...

# %%
train_y_tmp = train_y.copy()
test_y_tmp = test_y.copy()

train_y_tmp[train_y_tmp>20] = 20.0
pred_train_y[pred_train_y>20] = 20.0 
print('Train R-squared for LightGBM is %f' % r2_score(train_y_tmp, pred_train_y))
print('Train msre is: ' + str(sqrt(mean_squared_error(train_y_tmp, pred_train_y))))

if test_y is not None:
    test_y_tmp[test_y_tmp>20] = 20.0
    pred_test_y[pred_test_y>20] = 20.0 
    print('Test R-squared for LightGBM is %f' % r2_score(test_y_tmp, pred_test_y))
    print('Test msre is: ' + str(sqrt(mean_squared_error(test_y_tmp, pred_test_y))))
    
del train_y_tmp, test_y_tmp
gc.collect();
# Out:
# Train R-squared for LightGBM is 0.268050
# Train msre is: 1.0166271399383389
# Test R-squared for LightGBM is 0.107186
# Test msre is: 1.0735659013397745

# %% [markdown]
# ### Pick Most Important Features

# %%
feature_importances = pd.DataFrame(
    {
        'feature_name': feature_names,
        'feature_importance': model.feature_importance().tolist()
    }
)

feature_importances.sort_values('feature_importance', ascending=False, inplace=True)
important_feature_names = set(feature_importances[:30]['feature_name'].tolist())

important_feature_names

feature_boolean_mask = np.asarray(list(
    map(
        lambda feature_name: feature_name in important_feature_names,
        feature_names
    )
))

train_x = train_x[:, feature_boolean_mask]
test_x = test_x[:, feature_boolean_mask]

lgb_dataset = lgb.Dataset(train_x, label=train_y)

# %%
del model, train_x
gc.collect();

# %% [markdown]
# ## Hyper-parameter Tuning

# %%
def objective(hyper_param):
    
    print("hyper_params: " + str(hyper_param))
    max_depth, num_leaves, min_data_in_leaf = hyper_param
    
    lgb_params = {
               'feature_fraction': 0.75,
               'metric': 'rmse',
               'nthread':3, 
               'min_data_in_leaf': int(min_data_in_leaf), 
               'bagging_fraction': 0.75, 
               'learning_rate': 0.03, 
               'objective': 'mse', 
               'bagging_seed': 2**7, 
               'num_leaves': int(num_leaves),
               'max_depth': int(max_depth),
               'bagging_freq':1,
               'verbose':0 
              }
    print("start training...")
    model = lgb.train(lgb_params, lgb_dataset, 100)
    print("start prediction...")
    pred_test_y = model.predict(test_x)
    print("start estimation...")
    
    train_y_tmp = train_y.copy()
    test_y_tmp = test_y.copy()
    test_y_tmp[test_y_tmp>20] = 20.0
    pred_test_y[pred_test_y>20] = 20.0 
    result = sqrt(mean_squared_error(test_y_tmp, pred_test_y))
    print('Test msre is: ' + str(result))
    del train_y_tmp, test_y_tmp
    gc.collect();
    print("estimation done!")
    
    return result


# tuning algorithm
tpe_algo = tpe.suggest

# search space
space = [
    hp.quniform('max_depth', 5, 10, 1),
    hp.quniform('num_leaves', 2**5, 2**10, 5),
    hp.quniform('min_data_in_leaf', 2**5, 10**4, 5)
]

# history
tpe_trials = Trials()

# %%
# Run 2000 evals with the tpe algorithm
tpe_best = fmin(fn=objective, space=space, algo=tpe_algo, trials=tpe_trials, max_evals=1000, rstate= np.random.RandomState(50))

print(tpe_best)
# Out:
# hyper_params: (8.0, 1020.0, 5860.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0489852283746777
# estimation done!
# hyper_params: (8.0, 885.0, 4530.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0484295488979563
# estimation done!
# hyper_params: (9.0, 775.0, 9835.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0529061439142497
# estimation done!
# hyper_params: (7.0, 435.0, 655.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0256654398984903
# estimation done!
# hyper_params: (6.0, 40.0, 8950.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0533371222391328
# estimation done!
# hyper_params: (6.0, 405.0, 4390.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0539926454246016
# estimation done!
# hyper_params: (9.0, 660.0, 3755.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0467743984110414
# estimation done!
# hyper_params: (7.0, 305.0, 7800.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.052725270175449
# estimation done!
# hyper_params: (9.0, 555.0, 4425.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.046422771902942
# estimation done!
# hyper_params: (9.0, 775.0, 5535.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0480135168797728
# estimation done!
# hyper_params: (6.0, 585.0, 7245.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.053601648433423
# estimation done!
# hyper_params: (6.0, 835.0, 200.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0272364714298896
# estimation done!
# hyper_params: (10.0, 130.0, 2365.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0380943002252152
# estimation done!
# hyper_params: (6.0, 670.0, 6905.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0526738807409093
# estimation done!
# hyper_params: (7.0, 950.0, 4545.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0469845904950983
# estimation done!
# hyper_params: (5.0, 355.0, 7075.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0548726142570182
# estimation done!
# hyper_params: (7.0, 85.0, 5785.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0498507141721223
# estimation done!
# hyper_params: (10.0, 195.0, 9615.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0531865191298027
# estimation done!
# hyper_params: (5.0, 565.0, 975.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0277236464899961
# estimation done!
# hyper_params: (9.0, 1000.0, 5870.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.051521088763826
# estimation done!
# hyper_params: (7.0, 445.0, 80.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0278288494588421
# estimation done!
# hyper_params: (5.0, 255.0, 1395.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0340897792878345
# estimation done!
# hyper_params: (8.0, 460.0, 90.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0360510101128102
# estimation done!
# hyper_params: (6.0, 810.0, 2730.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0447366855183968
# estimation done!
# hyper_params: (7.0, 650.0, 1110.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.030645985333941
# estimation done!
# hyper_params: (5.0, 485.0, 2180.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.039661862309038
# estimation done!
# hyper_params: (6.0, 860.0, 3460.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0454934910661766
# estimation done!
# hyper_params: (8.0, 730.0, 520.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0265862463537982
# estimation done!
# hyper_params: (8.0, 735.0, 1740.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0319004814308508
# estimation done!
# hyper_params: (8.0, 370.0, 555.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0262293494085313
# estimation done!
# hyper_params: (8.0, 200.0, 3185.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.044563546442896
# estimation done!
# hyper_params: (8.0, 325.0, 670.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0291018974595538
# estimation done!
# hyper_params: (7.0, 380.0, 2915.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0408881006373643
# estimation done!
# hyper_params: (8.0, 265.0, 1625.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.032276846822096
# estimation done!
# hyper_params: (10.0, 495.0, 3780.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0472800163254121
# estimation done!
# hyper_params: (9.0, 410.0, 2150.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0373865522221313
# estimation done!
# hyper_params: (7.0, 165.0, 8525.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0566495673706036
# estimation done!
# hyper_params: (8.0, 620.0, 5315.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0474204709990773
# estimation done!
# hyper_params: (9.0, 510.0, 6345.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0492470008201173
# estimation done!
# hyper_params: (7.0, 270.0, 4885.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.049230187937749
# estimation done!
# hyper_params: (9.0, 420.0, 3960.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0457187480855352
# estimation done!
# hyper_params: (8.0, 40.0, 490.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.024462381048827
# estimation done!
# hyper_params: (7.0, 40.0, 2575.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0387982925452945
# estimation done!
# hyper_params: (6.0, 115.0, 1670.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0309053576527905
# estimation done!
# hyper_params: (10.0, 45.0, 1185.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0270198824061085
# estimation done!
# hyper_params: (9.0, 970.0, 4100.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.046538059933221
# estimation done!
# hyper_params: (6.0, 905.0, 7730.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0561673399301552
# estimation done!
# hyper_params: (7.0, 230.0, 1995.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0351472713132956
# estimation done!
# hyper_params: (8.0, 100.0, 3320.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0446820077695764
# estimation done!
# hyper_params: (9.0, 315.0, 9830.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0536704170479785
# estimation done!
# hyper_params: (7.0, 540.0, 9100.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.052017529886915
# estimation done!
# hyper_params: (8.0, 160.0, 275.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0277833402226932
# estimation done!
# hyper_params: (5.0, 705.0, 885.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0275796892261604
# estimation done!
# hyper_params: (6.0, 610.0, 40.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0324962709264682
# estimation done!
# hyper_params: (10.0, 60.0, 4825.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0458831181814312
# estimation done!
# hyper_params: (7.0, 800.0, 6290.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.05046907840687
# estimation done!
# hyper_params: (6.0, 135.0, 2935.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0435388456952013
# estimation done!
# hyper_params: (8.0, 895.0, 1345.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0322290598415191
# estimation done!
# hyper_params: (7.0, 220.0, 2450.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0385169501365437
# estimation done!
# hyper_params: (9.0, 335.0, 730.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0288418737225933
# estimation done!
# hyper_params: (5.0, 455.0, 1900.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0388397383835295
# estimation done!
# hyper_params: (8.0, 290.0, 4405.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.045876116531368
# estimation done!
# hyper_params: (6.0, 575.0, 455.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.025870115221238
# estimation done!
# hyper_params: (7.0, 660.0, 3615.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0478235175958002
# estimation done!
# hyper_params: (10.0, 755.0, 5250.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.048786765298929
# estimation done!
# hyper_params: (6.0, 565.0, 450.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0253954201725457
# estimation done!
# hyper_params: (5.0, 690.0, 1375.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0322633591573382
# estimation done!
# hyper_params: (6.0, 620.0, 270.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0283858027549218
# estimation done!
# hyper_params: (6.0, 525.0, 845.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0265320217824505
# estimation done!
# hyper_params: (5.0, 385.0, 1115.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0287074025329241
# estimation done!
# hyper_params: (7.0, 480.0, 3055.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0432443618221183
# estimation done!
# hyper_params: (6.0, 840.0, 1490.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0303887743926854
# estimation done!
# hyper_params: (6.0, 590.0, 2220.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.037144696375043
# estimation done!
# hyper_params: (7.0, 430.0, 2625.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0389756705209658
# estimation done!
# hyper_params: (8.0, 550.0, 70.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0345890021384296
# estimation done!
# hyper_params: (5.0, 930.0, 1835.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0393669021468148
# estimation done!
# hyper_params: (7.0, 770.0, 430.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0264137096782902
# estimation done!
# hyper_params: (8.0, 350.0, 2315.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0371363327211
# estimation done!
# hyper_params: (7.0, 680.0, 1040.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0266195366255835
# estimation done!
# hyper_params: (6.0, 70.0, 7950.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0571589777374442
# estimation done!
# hyper_params: (5.0, 400.0, 3990.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.05112464769008
# estimation done!
# hyper_params: (8.0, 475.0, 6645.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0502481614306507
# estimation done!
# hyper_params: (7.0, 725.0, 2065.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0357768764682664
# estimation done!
# hyper_params: (9.0, 635.0, 2700.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0427109523900193
# estimation done!
# hyper_params: (6.0, 795.0, 670.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0271639113467252
# estimation done!
# hyper_params: (7.0, 990.0, 5820.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0507228841328686
# estimation done!
# hyper_params: (9.0, 510.0, 1575.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0322220249772405
# estimation done!
# hyper_params: (8.0, 285.0, 320.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0273153345597201
# estimation done!
# hyper_params: (7.0, 430.0, 1260.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0303891098610043
# estimation done!
# hyper_params: (8.0, 1020.0, 3480.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0428730808165463
# estimation done!
# hyper_params: (6.0, 215.0, 835.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.02661487904175
# estimation done!
# hyper_params: (7.0, 245.0, 85.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0295863503359333
# estimation done!
# hyper_params: (5.0, 175.0, 4680.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0508091508338853
# estimation done!
# hyper_params: (8.0, 875.0, 3180.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0460664807171778
# estimation done!
# hyper_params: (6.0, 585.0, 1795.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0334503371978982
# estimation done!
# hyper_params: (6.0, 825.0, 4175.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.052361585109641
# estimation done!
# hyper_params: (8.0, 705.0, 9075.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.053113800581653
# estimation done!
# hyper_params: (7.0, 360.0, 2435.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0389629818513773
# estimation done!
# hyper_params: (9.0, 640.0, 7545.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0497604774031024
# estimation done!
# hyper_params: (5.0, 560.0, 2915.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0455712275892275
# estimation done!
# hyper_params: (7.0, 605.0, 595.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0272282463031894
# estimation done!
# hyper_params: (6.0, 145.0, 5585.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0496307947684143
# estimation done!
# hyper_params: (8.0, 100.0, 8630.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0523879830796339
# estimation done!
# hyper_params: (9.0, 190.0, 6225.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.051527771558693
# estimation done!
# hyper_params: (7.0, 390.0, 3720.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0467711768779724
# estimation done!
# hyper_params: (5.0, 530.0, 1065.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0297388085981494
# estimation done!
# hyper_params: (8.0, 500.0, 2030.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0363549359273014
# estimation done!
# hyper_params: (6.0, 450.0, 1500.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0307881917926758
# estimation done!
# hyper_params: (7.0, 740.0, 400.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0266427007007688
# estimation done!
# hyper_params: (10.0, 330.0, 200.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0331861467179657
# estimation done!
# hyper_params: (6.0, 465.0, 5090.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0525821036103755
# estimation done!
# hyper_params: (8.0, 255.0, 1230.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0314106040525293
# estimation done!
# hyper_params: (7.0, 670.0, 885.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0258348225114584
# estimation done!
# hyper_params: (6.0, 290.0, 2760.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.044699418812123
# estimation done!
# hyper_params: (5.0, 35.0, 1705.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0350146912041251
# estimation done!
# hyper_params: (7.0, 950.0, 2280.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0372510492798677
# estimation done!
# hyper_params: (9.0, 310.0, 715.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0267870454612273
# estimation done!
# hyper_params: (8.0, 785.0, 3230.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0428968934165246
# estimation done!
# hyper_params: (7.0, 520.0, 2510.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.039868419505434
# estimation done!
# hyper_params: (5.0, 115.0, 9515.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0569481639426284
# estimation done!
# hyper_params: (6.0, 700.0, 7170.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0525995119908187
# estimation done!
# hyper_params: (10.0, 855.0, 40.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0488863745044643
# estimation done!
# hyper_params: (7.0, 435.0, 4225.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0491164117780325
# estimation done!
# hyper_params: (9.0, 350.0, 1360.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0310754741959978
# estimation done!
# hyper_params: (8.0, 410.0, 8130.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0528919741779246
# estimation done!
# hyper_params: (8.0, 755.0, 520.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0265862463537982
# estimation done!
# hyper_params: (6.0, 600.0, 3830.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0489694147272266
# estimation done!
# hyper_params: (7.0, 80.0, 985.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0252708401888517
# estimation done!
# hyper_params: (7.0, 80.0, 6910.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0506401058446202
# estimation done!
# hyper_params: (5.0, 160.0, 3500.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0473375748779858
# estimation done!
# hyper_params: (6.0, 235.0, 4570.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0509191887221958
# estimation done!
# hyper_params: (7.0, 50.0, 1990.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0358011966313083
# estimation done!
# hyper_params: (9.0, 210.0, 970.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0285857676006551
# estimation done!
# hyper_params: (8.0, 185.0, 1625.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.032276846822096
# estimation done!
# hyper_params: (6.0, 150.0, 190.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.026014802892366
# estimation done!
# hyper_params: (7.0, 545.0, 6085.0)
# start training...
# start prediction...
# start estimation...
# Test msre is: 1.0507699172532101
# estimation done!
# hyper_params: (8.0, 125.0, 6565.0)
# start training...

# %%
# lgb_params = {
#                'feature_fraction': 0.75,
#                'metric': 'rmse',
#                'nthread':1, 
#                'min_data_in_leaf': 2**7, 
#                'bagging_fraction': 0.75, 
#                'learning_rate': 0.03, 
#                'objective': 'mse', 
#                'bagging_seed': 2**7, 
#                'num_leaves': 2**6,
#                'bagging_freq':1,
#                'verbose':0 
#               }
# model = lgb.train(lgb_params, lgb.Dataset(train_x, label=train_y), 100)

# pred_y = model.predict(train_x)
# print('Train R-squared for LightGBM is %f' % r2_score(train_y, pred_y))
    
# pred_y = model.predict(test_x)
# if test_y is not None:
#     print('Test R-squared for LightGBM is %f' % r2_score(test_y, pred_y))

# %%
# sqrt(mean_squared_error(test_y, pred_y))

# %%
# model = LinearRegression().fit(train_x, train_y)

# pred_y = model.predict(train_x)
# print('Train R-squared for LinearRegression is %f' % r2_score(train_y, pred_y))
    
# pred_y = model.predict(test_x)
# if test_y is not None:
#     print('Test R-squared for LinearRegression is %f' % r2_score(test_y, pred_y))

# %%
# sqrt(mean_squared_error(test_y, pred_y))
